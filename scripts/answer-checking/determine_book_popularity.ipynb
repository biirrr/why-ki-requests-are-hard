# %% [markdown]
# # Checking solved request book popularity
#
# For the solved book search requests, we want to have an indicator of book popularity. We use two source:
#
# 1. book item popularity: the popularity of the individual book. For this we use the Open Libary API to query for records of the correct answer book, and extract the `readinglog`
#
# 2. book genre popularity: the popularity of the genre of the book. For this we combine two sources:
#     - 1. the genre label in the title of the request,
#     - 2. the tags that user assigned to Goodreads book lists that they are interested in or contributed to.

# %%
import re
import urllib

import numpy as np
import pandas as pd
import requests

# %%
tsv_file = '../../data/2026-Why_are_complex_search_requests_so_difficult/solved threads (unchecked)/Books-solved.tsv'

df = pd.read_csv(tsv_file, sep='\t')
df.head(2)
# Out:
#    subreddit  thread_id  comment_id                  author_name  \
# 0  goodreads      13195           1                       Angela
# 1  goodreads      13195           2  Krista the Krazy Kataloguer
#
#               timestamp                                            comment  \
# 0  2008-08-05T00:00:00Z  A book about a child who goes to school, but s...
# 1  2008-08-05T00:00:00Z  Well, it sounds like The Bears' House by Maril...
#
#   solved answer LibraryThing_ID      notes
# 0    NaN    NaN             NaN  TW: abuse
# 1    NaN    NaN             NaN        NaN

# %% [markdown]
# ## Sanity checks
#
# The `subreddit` column must always be `goodreads` and the `comment_id` column must always be an integer.

# %%
df.subreddit.value_counts()
# Out:
# subreddit
# goodreads    12198
# Name: count, dtype: int64

# %%
df.comment_id.value_counts()
#df.comment_id.apply(lambda x: isinstance(x, int))
# Out:
# comment_id
# 1     1941
# 2     1921
# 3     1779
# 4     1434
# 5     1011
# 6      745
# 7      544
# 8      411
# 9      315
# 10     242
# 11     200
# 12     164
# 13     141
# 14     111
# 15      94
# 16      84
# 17      78
# 18      70
# 19      64
# 20      59
# 21      57
# 22      50
# 23      44
# 24      43
# 25      41
# 27      38
# 26      38
# 28      34
# 29      31
# 30      26
# 31      26
# 32      26
# 33      25
# 34      23
# 35      21
# 36      21
# 37      21
# 41      19
# 42      19
# 39      19
# 40      19
# 38      19
# 43      18
# 44      16
# 45      16
# 46      16
# 47      16
# 48      16
# 49      16
# 50      16
# Name: count, dtype: int64

# %% [markdown]
# ## Selecting answer rows

# %%
answer_df = df[df.answer.apply(lambda x: pd.notna(x) and x != '')]
answer_df.head(2)
# Out:
#     subreddit  thread_id  comment_id author_name             timestamp  \
# 16  goodreads      13195          14      Angela  2008-08-05T00:00:00Z
# 83  goodreads      37787          14     Deborah  2008-08-05T00:00:00Z
#
#                                               comment              solved  \
# 16  The book I was looking for is called Lovey by ...  solved / confirmed
# 83  It jumped into my head this morning - after ho...  solved / confirmed
#
#                                                answer LibraryThing_ID  \
# 16                        Lovey: A Very Special Child          272207
# 83  The Hite Report: A Nationwide Study of Female ...           71020
#
#                                                notes
# 16                                by Mary MacCracken
# 83  solved by the OP title according to LibraryThing

# %% [markdown]
# ### Add author information

# %%
def extract_author(note):
    if pd.isna(note):
        return np.nan
    if note.startswith('by ') is False:
        return np.nan
    if ' part of ' in note:
        part_idx = note.index(' part of ')
        #print(note[part_idx:])
        return note[3:part_idx]
    else:
        return note[3:]
        
df['has_author'] = df.notes.apply(lambda x: pd.isna(x) is False and x.startswith('by '))
df['author'] = df.notes.apply(extract_author)

# %%
df[df.author.notna()]
# Out:
#        subreddit  thread_id  comment_id   author_name             timestamp  \
# 16     goodreads      13195          14        Angela  2008-08-05T00:00:00Z
# 104    goodreads      55619           8           Tab  2019-08-05T00:00:00Z
# 127    goodreads     160509           2         karen  2016-08-05T00:00:00Z
# 129    goodreads     178121          37    The Flooze  2009-08-05T00:00:00Z
# 192    goodreads     205189           2         Misty  2009-08-05T00:00:00Z
# ...          ...        ...         ...           ...                   ...
# 12155  goodreads   23185338           2         tesla  2025-08-02T00:00:00Z
# 12169  goodreads   23186720           5         Juels  2025-07-30T00:00:00Z
# 12177  goodreads   23187261           2         Becca  2025-07-30T00:00:00Z
# 12182  goodreads   23187967           2  Genesistrine  2025-07-31T00:00:00Z
# 12184  goodreads   23190385           2  Rainbowheart  2025-08-02T00:00:00Z
#
#                                                  comment              solved  \
# 16     The book I was looking for is called Lovey by ...  solved / confirmed
# 104    It sounds like a book that Chronicle Books wou...              solved
# 127    i NEVER abandoned this! i kept hope alive! and...  solved / confirmed
# 129    Donbas: A True Story of an Escape Across Russi...              solved
# 192    Okay - I can't believe it, but I just found it...  solved / confirmed
# ...                                                  ...                 ...
# 12155                                           Menace ?              solved
# 12169  Secret Fire by Johanna Lindsey . This starts i...              solved
# 12177              A Touch of Shadows by Jessica Thorne?              solved
# 12182                                            Ariel ?              solved
# 12184                     The Young Traveler in Sweden ?              solved
#
#                                                   answer LibraryThing_ID  \
# 16                           Lovey: A Very Special Child          272207
# 104    Unforgettable: Images That Have Changed Our Lives         1564231
# 127                              Against Incredible Odds        19290779
# 129      Donbas: A True Story of an Escape Across Russia         8868250
# 192    Savage Inequalities: Children in America's Sch...           35301
# ...                                                  ...             ...
# 12155                                             Menace        18968629
# 12169                                        Secret Fire           79282
# 12177                                 A Touch of Shadows        32882005
# 12182                                              Ariel          157923
# 12184                       The Young Traveler in Sweden        20554465
#
#                                                    notes  has_author  \
# 16                                    by Mary MacCracken        True
# 104                                   by Peter Davenport        True
# 127                                       by Arthur Roth        True
# 129                                by Jacques Sandulescu        True
# 192                                    by Jonathan Kozol        True
# ...                                                  ...         ...
# 12155       by JM Darhower part of series: Scarlet Scars        True
# 12169                                 by Johanna Lindsey        True
# 12177   by Jessica Thorne part of series: The Lost Queen        True
# 12182     by Steven R. Boyett part of series: The Change        True
# 12184  by George L. Proctor part of series: The Young...        True
#
#                    author
# 16        Mary MacCracken
# 104       Peter Davenport
# 127           Arthur Roth
# 129    Jacques Sandulescu
# 192        Jonathan Kozol
# ...                   ...
# 12155         JM Darhower
# 12169     Johanna Lindsey
# 12177      Jessica Thorne
# 12182    Steven R. Boyett
# 12184   George L. Proctor
#
# [783 rows x 12 columns]

# %%
records = (df[(df.answer.notna()) & (df.answer != '')][['thread_id', 'answer', 'author']]
           .to_dict('records'))

# %% [markdown]
# ## Downloading Open Library work dump
#
# The Open Library website offers data dumps at different levels. See: https://openlibrary.org/developers/dumps
#
# The `works` dump contains all records at the work level (https://openlibrary.org/data/ol_dump_works_latest.txt.gz).
#
# The data in the file is tab-separated and has the following columns:
#
# - `type` - type of record (/type/edition, /type/work etc.)
# - `key` - unique key of the record (/books/OL1M etc.)
# - `revision` - revision number of the record
# - `last_modified` - last modified timestamp
# - `JSON` - the complete record in JSON format

# %%
import gzip
import json


dump_file = '/Volumes/T7_Data/Data/CHIIR-papers/why_ki_is_hard/ol_dump_works_2025-08-31.txt.gz'
headers = ['record_type', 'record_id', 'revision', 'last_modified', 'record']

with gzip.open(dump_file, 'rt') as fh:
    for line in fh:
        row = line.strip('\n').split('\t')
        row_record = {header: row[hi] for hi, header in enumerate(headers)}
        row_record['record'] = json.loads(row_record['record'])
        print(json.dumps(row_record, indent=4))
        break
# Out:
# {
#     "record_type": "/type/work",
#     "record_id": "/works/OL10000196W",
#     "revision": "3",
#     "last_modified": "2010-04-28T06:54:19.472104",
#     "record": {
#         "title": "Les mots-cl\u00e9s de l'\u00e9conomie",
#         "created": {
#             "type": "/type/datetime",
#             "value": "2009-12-11T01:57:19.964652"
#         },
#         "covers": [
#             3146541
#         ],
#         "last_modified": {
#             "type": "/type/datetime",
#             "value": "2010-04-28T06:54:19.472104"
#         },
#         "latest_revision": 3,
#         "key": "/works/OL10000196W",
#         "authors": [
#             {
#                 "type": "/type/author_role",
#                 "author": {
#                     "key": "/authors/OL3965197A"
#                 }
#             }
#         ],
#         "type": {
#             "key": "/type/work"
#         },
#         "revision": 3
#     }
# }

# %% [markdown]
# ## Querying the Open Library API
#
# Run all answer book titles against the API to get exact matches. This is to sanity check that runing the titles against the data dump returns at least the same exact matches. **Otherwise the API is doing something other than exact match.**

# %%
BASE_URL = "https://openlibrary.org/search.json"

def search_openlibrary(title, max_retries: int = 5):
    # url-encoded title and author
    title = re.sub(f' +', '+', title)
    title = urllib.parse.quote_plus(title)
    url = f'{BASE_URL}?q={title}&fields=*'
    response = requests.get(url)
    retry = 0
    while retry < max_retries:
        if response.status_code == 200:
            return response.json()
        else:
            print(response.status_code, f"retry {retry} of {max_retries}, error for title #{title}#")
            retry += 1
            time.sleep(2)

# %%
len(records)
# Out:
# 1481

# %% [markdown]
# Make the API requests:

# %%
import time

for ri, record in enumerate(records):
    title = record['answer']
    #record['response_q'] = search_openlibrary(title)
    if pd.isna(record['author']):
        record['response_qta'] = record['response_q']
    else:    
        title_author = f'{title} {record["author"]}'
        record['response_qta'] = search_openlibrary(title_author)
        time.sleep(2)
    if (ri+1) % 10 == 0:
        print(f"{ri+1} of {len(records)} records processed")
# Out:
# 10 of 1481 records processed
# 20 of 1481 records processed
# 30 of 1481 records processed
# 40 of 1481 records processed
# 50 of 1481 records processed
# 60 of 1481 records processed
# 70 of 1481 records processed
# 80 of 1481 records processed
# 90 of 1481 records processed
# 100 of 1481 records processed
# 110 of 1481 records processed
# 120 of 1481 records processed
# 130 of 1481 records processed
# 140 of 1481 records processed
# 150 of 1481 records processed
# 160 of 1481 records processed
# 170 of 1481 records processed
# 180 of 1481 records processed
# 190 of 1481 records processed
# 200 of 1481 records processed
# 210 of 1481 records processed
# 220 of 1481 records processed
# 230 of 1481 records processed
# 240 of 1481 records processed
# 250 of 1481 records processed
# 260 of 1481 records processed
# 270 of 1481 records processed
# 280 of 1481 records processed
# 290 of 1481 records processed
# 300 of 1481 records processed
# 310 of 1481 records processed
# 320 of 1481 records processed
# 330 of 1481 records processed
# 340 of 1481 records processed
# 350 of 1481 records processed
# 360 of 1481 records processed
# 370 of 1481 records processed
# 380 of 1481 records processed
# 390 of 1481 records processed
# 400 of 1481 records processed
# 410 of 1481 records processed
# 420 of 1481 records processed
# 430 of 1481 records processed
# 440 of 1481 records processed
# 450 of 1481 records processed
# 460 of 1481 records processed
# 470 of 1481 records processed
# 480 of 1481 records processed
# 490 of 1481 records processed
# 500 of 1481 records processed
# 510 of 1481 records processed
# 520 of 1481 records processed
# 530 of 1481 records processed
# 540 of 1481 records processed
# 550 of 1481 records processed
# 560 of 1481 records processed
# 570 of 1481 records processed
# 580 of 1481 records processed
# 590 of 1481 records processed
# 600 of 1481 records processed
# 610 of 1481 records processed
# 620 of 1481 records processed
# 630 of 1481 records processed
# 640 of 1481 records processed
# 650 of 1481 records processed
# 660 of 1481 records processed
# 670 of 1481 records processed
# 680 of 1481 records processed
# 690 of 1481 records processed
# 700 of 1481 records processed
# 710 of 1481 records processed
# 720 of 1481 records processed
# 730 of 1481 records processed
# 740 of 1481 records processed
# 750 of 1481 records processed
# 760 of 1481 records processed
# 770 of 1481 records processed
# 780 of 1481 records processed
# 790 of 1481 records processed
# 800 of 1481 records processed
# 810 of 1481 records processed
# 820 of 1481 records processed
# 830 of 1481 records processed
# 840 of 1481 records processed
# 850 of 1481 records processed
# 860 of 1481 records processed
# 870 of 1481 records processed
# 880 of 1481 records processed
# 890 of 1481 records processed
# 900 of 1481 records processed
# 910 of 1481 records processed
# 920 of 1481 records processed
# 930 of 1481 records processed
# 940 of 1481 records processed
# 950 of 1481 records processed
# 960 of 1481 records processed
# 970 of 1481 records processed
# 980 of 1481 records processed
# 990 of 1481 records processed
# 1000 of 1481 records processed
# 1010 of 1481 records processed
# 1020 of 1481 records processed
# 1030 of 1481 records processed
# 1040 of 1481 records processed
# 1050 of 1481 records processed
# 1060 of 1481 records processed
# 1070 of 1481 records processed
# 1080 of 1481 records processed
# 1090 of 1481 records processed
# 1100 of 1481 records processed
# 1110 of 1481 records processed
# 1120 of 1481 records processed
# 1130 of 1481 records processed
# 1140 of 1481 records processed
# 1150 of 1481 records processed
# 1160 of 1481 records processed
# 1170 of 1481 records processed
# 1180 of 1481 records processed
# 1190 of 1481 records processed
# 1200 of 1481 records processed
# 1210 of 1481 records processed
# 1220 of 1481 records processed
# 1230 of 1481 records processed
# 1240 of 1481 records processed
# 1250 of 1481 records processed
# 1260 of 1481 records processed
# 1270 of 1481 records processed
# 1280 of 1481 records processed
# 1290 of 1481 records processed
# 1300 of 1481 records processed
# 1310 of 1481 records processed
# 1320 of 1481 records processed
# 1330 of 1481 records processed
# 1340 of 1481 records processed
# 1350 of 1481 records processed
# 1360 of 1481 records processed
# 1370 of 1481 records processed
# 1380 of 1481 records processed
# 1390 of 1481 records processed
# 1400 of 1481 records processed
# 1410 of 1481 records processed
# 1420 of 1481 records processed
# 1430 of 1481 records processed
# 1440 of 1481 records processed
# 1450 of 1481 records processed
# 1460 of 1481 records processed
# 1470 of 1481 records processed
# 1480 of 1481 records processed

# %%
import gzip
import glob
import json
import re


BASE_FILENAME = '../../data/books/records-open_library-request_answers'

def get_records_files():
    return glob.glob(f'{BASE_FILENAME}_v*.json.gz')


def get_records_file_version(records_file):
    if m := re.search(r"_v(\d+)\.json.gz$", records_file):
        return int(m.group(1))
    else:
        raise ValueError(f"invalid records_file name {records_file}.")
    return None


def get_records_file_versions():
    records_files = get_records_files()
    return [(get_records_file_version(rf), rf) for rf in records_files]


def get_records_lastest_file():
    version_num = determine_last_version_number()
    return (f'{BASE_FILENAME}_v{version_num}.json.gz')

    
def determine_new_version_number():
    return determine_last_version_number() +1


def determine_last_version_number():
    file_versions = get_records_file_versions()
    if len(file_versions) == 0:
        return 0
    latest = max(version for version, _ in file_versions)
    return latest

# %% [markdown]
# Store the results:

# %%
version_num = determine_new_version_number()
records_file = f'../../data/books/records-open_library-request_answers_v{version_num}.json.gz'

if len(records) == 1481 and all('response' in record for record in records):
    with gzip.open(records_file, 'wt') as fh:
        json.dump(records, fh)

# %% [markdown]
# Read the results from file:

# %%
records_file = get_records_lastest_file()

with gzip.open(records_file, 'rt') as fh:
    records = json.load(fh)

# %% [markdown]
# ## Extracting Genre Information

# %%
for record in records:
    #print(record)
    docs = record['response_qta']['docs']
    subjects = [doc['subject'] for doc in docs if 'subject' in doc]
    subjects = [subject for subject_list in subjects for subject in subject_list]
    lccs = [doc['lcc'] for doc in docs if 'lcc' in doc]
    print(lccs)
    print(set(subjects))
    break
# Out:
# [['HV-6626.52000000', 'RJ-0506.00000000.P63'], ['RJ-0505.00000000.M54 M3 1976b', 'RJ-0505.00000000.M54 M3']]
# {'Child psychotherapy', 'Mental Disorders', 'Mentally ill children, education', 'Large type books', 'Milieu therapy', 'Case studies', 'Problem children', 'Popular works', 'Child psychology', 'Psychotherapy', 'Children, biography', 'Emotionally disturbed children', 'Mentally ill children', 'In infancy and childhood', 'Education', 'Cases, clinical reports, statistics'}

# %% [markdown]
# #### Goodreads genres
#
# The main genres on Goodreads, taken from the main page:
#
# Art
# Biography
# Business
# Children's
# Christian
# Classics
# Comics
# Cookbooks
# Ebooks
# Fantasy
# Fiction
# Graphic Novels
# Historical Fiction
# History
# Horror
# Memoir
# Music
# Mystery
# Nonfiction
# Poetry
# Psychology
# Romance
# Science
# Science Fiction
# Self Help
# Sports
# Thriller
# Travel
# Young Adult
# More genres

# %%
genre_map_gr = {
    'Art': 'Art',
    'Biography': 'Biography',
    'Business': 'Business',
    "Children's": "Children's",
    'Christian': 'Christian',
    'Classics': 'Classics',
    'Comics': 'Comics',
    'Cookbooks': 'Cookbooks',
    'Ebooks': 'Ebooks',
    'Fantasy': 'Fantasy',
    'Fiction': 'Fiction',
    'Graphic Novels': 'Graphic Novels',
    'Historical Fiction': 'Historical Fiction',
    'History': 'History',
    'Horror': 'Horror',
    'Memoir': 'Memoir',
    'Music': 'Music',
    'Mystery': 'Mystery',
    'Nonfiction': 'Nonfiction',
    'Poetry': 'Poetry',
    'Psychology': 'Psychology',
    'Romance': 'Romance',
    'Science': 'Science',
    'Science Fiction': 'Science Fiction',
    'Self Help': 'Self Help',
    'Sports': 'Sports',
    'Thriller': 'Thriller',
    'Travel': 'Travel',
    'Young Adult': 'Young Adult'
    
}

# %% [markdown]
# Extend the list of genres with genres found in the thread titles, mapping them to normalised/standardised genre labels:

# %%
import os


def extract_genre(title):
    if title is None:
        return None
    for genre in genre_map_gr:
        if genre.lower() in title.lower():
            return genre_map_gr[genre]
    for genre in genre_map_upper:
        if genre in title:
            return genre_map_upper[genre]
    for genre in genre_map_title:
        if genre in title.lower():
            return genre_map_title[genre]
    # Fallback on indicator of fiction
    for genre in ['novel', ' fiction', 'adult']:
        if genre in title.lower():
            return 'Fiction'
    return None
    

genre_map_title = {
    'ya fantasy': 'Young Adult',
    'ya fiction': 'Young Adult',
    'ya romance': 'Young Adult',
    'ya book': 'Young Adult',
    'y/a': 'Young Adult',
    'scifi': 'Science Fiction',
    'sci-fi': 'Science Fiction',
    'sci/fi': 'Science Fiction',
    'science fiction': 'Science Fiction',
    'thriller': 'Thriller',
    'adult fantasy': 'Fantasy',
    'fantasy': 'Fantasy',
    'adult romance': 'Romance',
    'romance novel': 'Romance',
    'erotica': 'Romance',
    'historical romance': 'Romance',
    'historical fiction': 'Historical Fiction',
    'adult fiction': 'Fiction',
    'adult non-fiction': 'Nonfiction',
    'non-fiction': 'Nonfiction',
    'non fiction': 'Nonfiction',
    'memoir': 'Memoir',
    'historical': 'Historical Fiction',
    'ya short': 'Young Adult',
    'sci fi': 'Science Fiction',
    'ya teenage': 'Young Adult',
    'short story': 'Short story',
    'short stories': 'Short story',
    'ya novel': 'Young Adult',
    'suspence': 'Thriller',
    'romantic': 'Romance',
    'rom com': 'Romance',
    'non-fic': 'Nonfiction',
    'crime': 'Thriller',
    'graphic novel': 'Comics',
    'comic book': 'Comics',
    'childrens': "Children's",
    'kids': "Children's",
    'drama': 'Fiction',
    'teen': 'Young Adult',
    "children’s": "Children's",
    'adult novel': 'Fiction'
}

genre_map_upper = {
    'YA': 'Young Adult',
    'SF': 'Science Fiction'
}

parsed_thread_dir = '../../data/books/goodreads_crawl/parsed_threads-2025-08-05/'

parsed_thread_files = glob.glob(os.path.join(parsed_thread_dir, '*.json'))

# for genre in genre_map:
#     title = 'Harlequin historical romance about two sisters one was named cat which was the nick name of the evil twin sister'
#     print([genre, genre in title.lower()])
#     print(extract_genre(title))

no_genre = []
yes_genre = []
thread_genre = {}
for pi, ptf in enumerate(parsed_thread_files):
    with open(ptf, 'rt') as fh:
        thread = json.load(fh)
        title = thread['messages'][0]['thread_title']
        genre = extract_genre(title)
        if genre is None:
            no_genre.append([thread['thread_id'], title, None])
        else:
            yes_genre.append([thread['thread_id'], title, genre])
        thread_genre[thread['thread_id']] = genre

len(yes_genre), len(no_genre)
# Out:
# (2380, 344)

# %%
missing = len(no_genre) / (len(yes_genre) + len(no_genre))
print(f"fraction of threads with no genre information: {missing: >.4f}")
# Out:
# fraction of threads with no genre information: 0.1263

# %% [markdown]
# ### Extracting Genre Popularity Information
#
# Goodreads has public book lists that have a title and description to clarify the scope of the list, and that users can add books to and where they can upvote individual book titles. Users can also add tags to individual lists. The most common tags for list are all genre labels.
#
# Via the genre tags, the book lists can be used as an indicator of popularity. The number of public book lists with a given genre tag are an indicator of that genre's popularity.

# %%
# copy-and-paste of the most popular book tags and in parentheses, the number of book lists with that tag
gr_list_tags = """
romance (8174)fiction (7764)young-adult (5880)fantasy (5348)science-fiction (3687)non-fiction (3111)children (2526)history (2351)covers (2323)mystery (2243)horror (2154)historical-fiction (1922)gay (1820)titles (1715)best (1616)middle-grade (1569)nonfiction (1509)queer (1507)paranormal (1507)historical-romance (1458)lgbt (1447)love (1431)contemporary (1417)thriller (1385)title-challenge (1297)women (1288)lgbtq (1287)biography (1240)title (1190)classics (1176)"""

genres_counts = [item.strip() for item in re.split(r"\((\d+)\)", gr_list_tags.strip()) if item != '']
genre_popularity = {genres_counts[i]: genres_counts[i+1] for i in range(0, len(genres_counts), 2)}
genre_popularity
#len(genres_counts)
#genres_counts
# Out:
# {'romance': '8174',
#  'fiction': '7764',
#  'young-adult': '5880',
#  'fantasy': '5348',
#  'science-fiction': '3687',
#  'non-fiction': '3111',
#  'children': '2526',
#  'history': '2351',
#  'covers': '2323',
#  'mystery': '2243',
#  'horror': '2154',
#  'historical-fiction': '1922',
#  'gay': '1820',
#  'titles': '1715',
#  'best': '1616',
#  'middle-grade': '1569',
#  'nonfiction': '1509',
#  'queer': '1507',
#  'paranormal': '1507',
#  'historical-romance': '1458',
#  'lgbt': '1447',
#  'love': '1431',
#  'contemporary': '1417',
#  'thriller': '1385',
#  'title-challenge': '1297',
#  'women': '1288',
#  'lgbtq': '1287',
#  'biography': '1240',
#  'title': '1190',
#  'classics': '1176'}

# %%
genre_lists = {
    'Romance': 8174,
    'Fiction': 7764,
    'Young Adult': 5880,
    'Fantasy': 5348,
    'Science Fiction': 3687,
    'Nonfiction': 3111,
    "Children's": 2526,
    'History': 2351,
    'Mystery': 2243,
    'Horror': 2154,
    'Historical Fiction': 1922,
    'Paranormal': 1507,
    'Historical-romance': 1458,
    'Thriller': 1385,
    'Biography': 1240,
    'Classics': 1176,
    'Memoir': 1104,
    'Poetry': 973,
    'Art': 897,
    'Christian': 788,
    'Science': 783,
    'Comics': 759,
    'Travel': 690,
    'Music': 563,
    'Psychology': 512,
    'Business': 438,
    'Self Help': 432,
    'Short story': 190,
    'Sports': 125
}

# %%
import requests
from collections import Counter

genre_freq = Counter([genre_info[-1] for genre_info in yes_genre])
for genre, freq in genre_freq.most_common():
    if genre in genre_lists:
        #print(genre, freq, genre_pop[genre])
        continue
    print(genre, freq)

# %% [markdown]
# ## Extracting Popularity Information

# %%
popularity_fields = [
    'edition_count',
    'osp_count',
    'ratings_count'
]

popularity_len_fields = [
    'language'
]
doc
record = records[-1]
for doc in record['response_qta']['docs']:
    if 'ratings_average' in doc:
        print(json.dumps(doc, indent=4))
# Out:
# {
#     "author_alternative_name": [
#         "Francis Bacon",
#         "Sir Francis Bacon",
#         "Francis Bacon Viscount St. Albans",
#         "Bacon, Francis Viscount St. Albans",
#         "Francis Bacon, Baron Verulam, Viscount St. Albans, etc",
#         "Bacon, Francis viscount St. Albans",
#         "1626",
#         "Francis Bacon, John Milton, Thomas Browne",
#         "Francis Bacon, John Milton, Sir Thomas Browne"
#     ],
#     "author_key": [
#         "OL23720A"
#     ],
#     "author_name": [
#         "Francis Bacon"
#     ],
#     "contributor": [
#         "Rawley, William, 1588?-1667",
#         "Va\u0301zquez, Juan Adolfo, 1917- ed. and tr.",
#         "Smith, G. C. Moore 1858-1940",
#         "Haines, Richard, 1633-1685",
#         "Rawley, William, 1588?-1667.",
#         "R. H.",
#         "R., M.",
#         "Bartolozzi, Roberto, ed. and tr.",
#         "R.H.",
#         "George Fabyan Collection (Library of Congress)",
#         "R. H",
#         "Haines, Richard, 1633-1685.",
#         "Raquet, Gilles Bernard",
#         "English Printing Collection (Library of Congress)",
#         "H., R.",
#         "Osborne, Harold, 1905-1987, (Ed.)",
#         "Bacon, Francis, 1561-1626.",
#         "Campanella, Tommaso, 1568-1639.",
#         "M.R.",
#         "Gough, Alfred B."
#     ],
#     "cover_edition_key": "OL3684616M",
#     "cover_i": 313890,
#     "ddc": [
#         "335.02",
#         "321.07"
#     ],
#     "ebook_access": "public",
#     "ebook_count_i": 4,
#     "edition_count": 84,
#     "edition_key": [
#         "OL6207483M",
#         "OL12399665M",
#         "OL39217688M",
#         "OL37692522M",
#         "OL38496488M",
#         "OL6651904M",
#         "OL37094004M",
#         "OL37094038M",
#         "OL37103143M",
#         "OL37515292M",
#         "OL37528153M",
#         "OL36785842M",
#         "OL36797672M",
#         "OL35356915M",
#         "OL35362300M",
#         "OL35400616M",
#         "OL35648528M",
#         "OL34208412M",
#         "OL35263520M",
#         "OL35308594M",
#         "OL35950956M",
#         "OL36458705M",
#         "OL36547420M",
#         "OL36609959M",
#         "OL33052264M",
#         "OL30373808M",
#         "OL32306827M",
#         "OL32334275M",
#         "OL32492473M",
#         "OL27804809M",
#         "OL35266899M",
#         "OL27482071M",
#         "OL27598030M",
#         "OL29202694M",
#         "OL29542805M",
#         "OL29907769M",
#         "OL24952024M",
#         "OL24431545M",
#         "OL12557728M",
#         "OL9477508M",
#         "OL24324661M",
#         "OL24312359M",
#         "OL6499533M",
#         "OL6436247M",
#         "OL26970706M",
#         "OL16753607M",
#         "OL8501220M",
#         "OL9793524M",
#         "OL8501009M",
#         "OL20920385M",
#         "OL14705539M",
#         "OL839831M",
#         "OL907457M",
#         "OL857297M",
#         "OL20920382M",
#         "OL12436365M",
#         "OL20920383M",
#         "OL9834723M",
#         "OL20800462M",
#         "OL8501343M",
#         "OL8408047M",
#         "OL20920389M",
#         "OL839705M",
#         "OL2535974M",
#         "OL20920374M",
#         "OL15031432M",
#         "OL13542187M",
#         "OL20920371M",
#         "OL24290822M",
#         "OL15023480M",
#         "OL20920332M",
#         "OL21250725M",
#         "OL8501041M",
#         "OL15195488M",
#         "OL8660471M",
#         "OL20920381M",
#         "OL834989M",
#         "OL14449685M",
#         "OL13895300M",
#         "OL3684616M",
#         "OL14632323M",
#         "OL9722176M",
#         "OL19703496M",
#         "OL6556937M"
#     ],
#     "first_publish_year": 1627,
#     "first_sentence": [
#         "WE sailed from Peru (where we had continued by the space of one whole year), for China and Japan, by the South Sea, taking with us victuals for twelve months; and had good winds from the east, though soft and weak, for five months' space and more; but then the wind came about, and settled in the west for many days, so as we could make little or no way, and were sometimes in purpose to turn back."
#     ],
#     "format": [
#         "paperback",
#         "Microform",
#         "hardcover",
#         "Audio cassette",
#         "eBook",
#         "Paperback",
#         "Mass Market Paperback",
#         "mp3 cd"
#     ],
#     "has_fulltext": true,
#     "ia": [
#         "newatlantis642baco",
#         "fnewatlantis00baco",
#         "newatlantis0000baco"
#     ],
#     "ia_collection": [
#         "internetarchivebooks",
#         "printdisabled",
#         "thomasfisher",
#         "toronto",
#         "university_of_toronto"
#     ],
#     "ia_collection_s": "internetarchivebooks;printdisabled;thomasfisher;toronto;university_of_toronto",
#     "isbn": [
#         "9781612034515",
#         "9786051069166",
#         "9798460603619",
#         "1612034519",
#         "1406504149",
#         "9781599867618",
#         "9781387788330",
#         "1788940989",
#         "9781609423070",
#         "9798589258097",
#         "6057775724",
#         "1425004202",
#         "9786052493083",
#         "9780353245761",
#         "0486430820",
#         "1425010156",
#         "1595479007",
#         "315006645X",
#         "1932681167",
#         "9781981029914",
#         "1776762819",
#         "1434102041",
#         "9780486430829",
#         "1425004717",
#         "1099761824",
#         "9781600968853",
#         "9798468159613",
#         "9782080707703",
#         "1504063821",
#         "6050206554",
#         "9781521861028",
#         "0343205858",
#         "605106916X",
#         "9780723100416",
#         "1425015034",
#         "1604241160",
#         "9781595479006",
#         "1594627525",
#         "9781107663640",
#         "1599867613",
#         "9781425010157",
#         "9786050206555",
#         "9781412180955",
#         "9759971186",
#         "6052493089",
#         "1627300678",
#         "1521861021",
#         "9780343205850",
#         "9781099761829",
#         "9781594627521",
#         "9798794003901",
#         "9781518830464",
#         "9781788940986",
#         "9798589256987",
#         "9783150066454",
#         "1600968856",
#         "9781604241167",
#         "9781425015039",
#         "1546607099",
#         "0543978400",
#         "0723100411",
#         "9798713293970",
#         "1387788337",
#         "9781775410508",
#         "1412180953",
#         "1775410501",
#         "9798754700376",
#         "9780343205867",
#         "9780893144197",
#         "9781546607090",
#         "9781627300674",
#         "9780543978400",
#         "9781625580849",
#         "1564592308",
#         "2080707701",
#         "1609423070",
#         "9781434102041",
#         "9781564592309",
#         "1981029915",
#         "0893144193",
#         "1625580843",
#         "1434101894",
#         "9798525974746",
#         "9781776762811",
#         "0343205866",
#         "9781425004712",
#         "1107663644",
#         "0353245763",
#         "9789759971182",
#         "9780766108431",
#         "9781425004200",
#         "0766108430",
#         "9781932681161",
#         "1518830463",
#         "9786057775726",
#         "9781504063821",
#         "9781434101891",
#         "9781406504149"
#     ],
#     "key": "/works/OL69453W",
#     "language": [
#         "eng",
#         "und",
#         "fre",
#         "ger",
#         "rus",
#         "ita",
#         "spa"
#     ],
#     "last_modified_i": 1743186026,
#     "lcc": [
#         "HX-0811.00000000 S95 1664",
#         "HX-0811.00000000 1660",
#         "HX-0811.00000000.B33",
#         "B--1195.00000000.N48 1992",
#         "PR-2207.00000000",
#         "Q--0155.00000000.B14 S95 1631",
#         "HX-0811.00000000 S95 1627",
#         "HX-0811.00000000 S95 1629",
#         "Q--0155.00000000.B14 S95 1639",
#         "HX-0811.00000000.B33 2003",
#         "Q--0155.00000000.B14 S95 1635",
#         "QH-0041.00000000.B17",
#         "QH-0041.00000000.B15",
#         "PR-2206.00000000.Z8 A4",
#         "Q--0155.00000000.B14 S95 1664",
#         "HX-0811.00000000 S95 1639",
#         "HX-0811.00000000 S95 1635",
#         "HX-0811.00000000 S95 1631",
#         "Q--0155.00000000.B14 S95 1627",
#         "Q--0155.00000000.B14 S95 1629",
#         "QH-0155.00000000.B14 S95 1658"
#     ],
#     "lccn": [
#         "23002634",
#         "a15002478",
#         "56027316",
#         "95139243",
#         "13010011",
#         "95116428",
#         "95110105",
#         "2003046193",
#         "15002478",
#         "46007201",
#         "42015141",
#         "95201652",
#         "85016785",
#         "95116280"
#     ],
#     "lending_edition_s": "OL24952024M",
#     "lending_identifier_s": "newatlantis642baco",
#     "number_of_pages_median": 60,
#     "oclc": [
#         "8115754",
#         "33927528",
#         "10239112",
#         "53032474",
#         "535713189",
#         "15481511",
#         "35016892",
#         "11128850",
#         "156827507",
#         "231336705",
#         "859021330",
#         "22390419",
#         "30083188",
#         "7377126",
#         "426142991",
#         "55480372"
#     ],
#     "osp_count": 471,
#     "printdisabled_s": "OL20800462M",
#     "public_scan_b": true,
#     "publish_date": [
#         "2008",
#         "2010",
#         "Oct 15, 2018",
#         "Oct 28, 2014",
#         "1639",
#         "1659",
#         "September 6, 2007",
#         "Aug 12, 2018",
#         "May 10, 2017",
#         "1660",
#         "Aug 27, 2018",
#         "2021",
#         "1628",
#         "Jun 26, 2018",
#         "Oct 19, 2013",
#         "1925",
#         "Jul 16, 2017",
#         "1929",
#         "January 30, 2006",
#         "2003",
#         "1631",
#         "Oct 27, 2018",
#         "1941",
#         "Sep 19, 2019",
#         "1944",
#         "Feb 01, 2012",
#         "August 27, 2007",
#         "2009",
#         "March 1997",
#         "September 11, 2001",
#         "Oct 17, 2021",
#         "Nov 10, 2018",
#         "1702",
#         "2014",
#         "Nov 07, 2017",
#         "1635",
#         "2016",
#         "1664",
#         "1658",
#         "1954",
#         "October 1, 2006",
#         "Oct 29, 1801",
#         "2020",
#         "2019",
#         "July 15, 2000",
#         "1992",
#         "June 4, 2007",
#         "June 20, 2007",
#         "1627",
#         "January 2, 1997",
#         "Oct 30, 2020",
#         "1651",
#         "1924",
#         "1985",
#         "1629",
#         "2012",
#         "2022"
#     ],
#     "publish_place": [
#         "[Roma]",
#         "Buenos Aires",
#         "[London?",
#         "Girard, Kansas",
#         "Mineola, N.Y",
#         "Ottawa",
#         "Kila, Mont",
#         "Oxford",
#         "Cambridge",
#         "Waiheke Island",
#         "Moskva",
#         "Sioux Falls",
#         "Paris",
#         "Stuttgart, Germany",
#         "[London",
#         "Los Angeles, Calif",
#         "London"
#     ],
#     "publish_year": [
#         1664,
#         1924,
#         1925,
#         1629,
#         1801,
#         1929,
#         1941,
#         1944,
#         1954,
#         1702,
#         1985,
#         1992,
#         1997,
#         2000,
#         2001,
#         2003,
#         2006,
#         2007,
#         2008,
#         2009,
#         2010,
#         1627,
#         2012,
#         2013,
#         2014,
#         1631,
#         2016,
#         2017,
#         2018,
#         2019,
#         2020,
#         2021,
#         2022,
#         1635,
#         1639,
#         1651,
#         1658,
#         1659,
#         1660,
#         1628
#     ],
#     "publisher": [
#         "Colombo",
#         "Franklin Classics Trade Press",
#         "NuVision Publications",
#         "Information Age Publishing, Incorporated",
#         "Kabalci Yayinevi",
#         "Printed for John Crooke ...",
#         "Printed by Tho. Newcomb",
#         "Independently Published",
#         "IDB Productions",
#         "Printed by J. Haviland for W. Lee",
#         "Philosophical Research Society",
#         "Zeplin Kitap",
#         "Alfa Yayincilik",
#         "Printed by J.H. for William Lee ...",
#         "Printed by John Haviland for William Lee and are to be sold by Iohn Williams",
#         "University of Cambridge ESOL Examinations",
#         "Discovery Publisher",
#         "ReadHowYouWant.com",
#         "Createspace Independent Publishing Platform",
#         "Haldeman-Julius Co.",
#         "eBooksLib",
#         "Open Road Integrated Media, Inc.",
#         "Start Publishing LLC",
#         "Flammarion",
#         "The Editorium, LLC",
#         "Dodo Press",
#         "Oxford University Press",
#         "Editorial Losada, s.a.",
#         "Clarendon Press",
#         "Adamant Media Corporation",
#         "Printed by John Haviland for William Lee ...",
#         "Stonewell Press",
#         "Lulu.com",
#         "Franklin Classics",
#         "J. Musier",
#         "Sine nomine",
#         "CreateSpace Independent Publishing Platform",
#         "Printed by J.F. and S.G. for William Lee ...",
#         "Dorlion Yayinevi",
#         "The Floating Press",
#         "Kessinger",
#         "Reclam-Verlag",
#         "Univ.Tut.P.",
#         "Printed by J. Haviland, for W. Lee",
#         "Kessinger Publishing",
#         "Dover Publications",
#         "Izd-vo Akademii nauk SSSR",
#         "J. Crooke",
#         "FQ Classics",
#         "Say Yayinlari",
#         "Bottom of the Hill Publishing",
#         "Independently published",
#         "University Press",
#         "Book Jungle"
#     ],
#     "seed": [
#         "/books/OL6207483M",
#         "/books/OL12399665M",
#         "/books/OL39217688M",
#         "/books/OL37692522M",
#         "/books/OL38496488M",
#         "/books/OL6651904M",
#         "/books/OL37094004M",
#         "/books/OL37094038M",
#         "/books/OL37103143M",
#         "/books/OL37515292M",
#         "/books/OL37528153M",
#         "/books/OL36785842M",
#         "/books/OL36797672M",
#         "/books/OL35356915M",
#         "/books/OL35362300M",
#         "/books/OL35400616M",
#         "/books/OL35648528M",
#         "/books/OL34208412M",
#         "/books/OL35263520M",
#         "/books/OL35308594M",
#         "/books/OL35950956M",
#         "/books/OL36458705M",
#         "/books/OL36547420M",
#         "/books/OL36609959M",
#         "/books/OL33052264M",
#         "/books/OL30373808M",
#         "/books/OL32306827M",
#         "/books/OL32334275M",
#         "/books/OL32492473M",
#         "/books/OL27804809M",
#         "/books/OL35266899M",
#         "/books/OL27482071M",
#         "/books/OL27598030M",
#         "/books/OL29202694M",
#         "/books/OL29542805M",
#         "/books/OL29907769M",
#         "/books/OL24952024M",
#         "/books/OL24431545M",
#         "/books/OL12557728M",
#         "/books/OL9477508M",
#         "/books/OL24324661M",
#         "/books/OL24312359M",
#         "/books/OL6499533M",
#         "/books/OL6436247M",
#         "/books/OL26970706M",
#         "/books/OL16753607M",
#         "/books/OL8501220M",
#         "/books/OL9793524M",
#         "/books/OL8501009M",
#         "/books/OL20920385M",
#         "/books/OL14705539M",
#         "/books/OL839831M",
#         "/books/OL907457M",
#         "/books/OL857297M",
#         "/books/OL20920382M",
#         "/books/OL12436365M",
#         "/books/OL20920383M",
#         "/books/OL9834723M",
#         "/books/OL20800462M",
#         "/books/OL8501343M",
#         "/books/OL8408047M",
#         "/books/OL20920389M",
#         "/books/OL839705M",
#         "/books/OL2535974M",
#         "/books/OL20920374M",
#         "/books/OL15031432M",
#         "/books/OL13542187M",
#         "/books/OL20920371M",
#         "/books/OL24290822M",
#         "/books/OL15023480M",
#         "/books/OL20920332M",
#         "/books/OL21250725M",
#         "/books/OL8501041M",
#         "/books/OL15195488M",
#         "/books/OL8660471M",
#         "/books/OL20920381M",
#         "/books/OL834989M",
#         "/books/OL14449685M",
#         "/books/OL13895300M",
#         "/books/OL3684616M",
#         "/books/OL14632323M",
#         "/books/OL9722176M",
#         "/books/OL19703496M",
#         "/books/OL6556937M",
#         "/works/OL69453W",
#         "/authors/OL23720A",
#         "/subjects/early_works_to_1800",
#         "/subjects/education",
#         "/subjects/natural_history",
#         "/subjects/philosophy",
#         "/subjects/philosophy_of_nature",
#         "/subjects/political_science",
#         "/subjects/pre-linnean_works",
#         "/subjects/science",
#         "/subjects/the_state",
#         "/subjects/utopias",
#         "/subjects/fiction_historical_general",
#         "/subjects/nonfiction",
#         "/subjects/fiction",
#         "/subjects/short_stories",
#         "/subjects/fiction_general",
#         "/subjects/fiction_classics",
#         "/subjects/fiction_city_life"
#     ],
#     "title": "Nova Atlantis",
#     "title_sort": "Nova Atlantis",
#     "title_suggest": "Nova Atlantis",
#     "type": "work",
#     "id_goodreads": [
#         "3494311",
#         "2864346",
#         "4160732",
#         "277034",
#         "1276700",
#         "4160729",
#         "1623207",
#         "1276701",
#         "277032",
#         "1956317",
#         "7180655",
#         "1623207",
#         "1561075",
#         "2089291"
#     ],
#     "id_librarything": [
#         "193418",
#         "193418",
#         "193418",
#         "193418",
#         "193418",
#         "193418",
#         "193418",
#         "2323020",
#         "193418",
#         "193418",
#         "400992",
#         "193418"
#     ],
#     "id_amazon": [
#         "1788940989",
#         "1627300678",
#         "1612034519"
#     ],
#     "id_overdrive": [
#         "AD78D83E-6FA1-45C0-925E-FED123D9C3E0",
#         "284331C4-1214-48C3-9A26-7AFC95202F32",
#         "0A54824E-5F01-4E9E-AEA5-851DDC9D4CFD"
#     ],
#     "id_freebase": [
#         "m/05tyx8"
#     ],
#     "id_dnb": [
#         "1041837550"
#     ],
#     "id_project_gutenberg": [
#         "2434"
#     ],
#     "subject": [
#         "Early works to 1800",
#         "Education",
#         "Natural history",
#         "Philosophy",
#         "Philosophy of nature",
#         "Political science",
#         "Pre-Linnean works",
#         "Science",
#         "The State",
#         "Utopias",
#         "Fiction, historical, general",
#         "Nonfiction",
#         "Fiction",
#         "Short Stories",
#         "Fiction, general",
#         "Fiction, classics",
#         "Fiction, city life"
#     ],
#     "ia_loaded_id": [
#         "newatlantis642baco"
#     ],
#     "ia_box_id": [
#         "IA108803"
#     ],
#     "ratings_average": 3.5,
#     "ratings_sortable": 2.416337,
#     "ratings_count": 2,
#     "ratings_count_1": 0,
#     "ratings_count_2": 0,
#     "ratings_count_3": 1,
#     "ratings_count_4": 1,
#     "ratings_count_5": 0,
#     "readinglog_count": 52,
#     "want_to_read_count": 47,
#     "currently_reading_count": 2,
#     "already_read_count": 3,
#     "trending_score_hourly_11": 0,
#     "trending_score_hourly_10": 0,
#     "trending_score_hourly_13": 0,
#     "trending_score_hourly_12": 0,
#     "trending_score_hourly_14": 0,
#     "trending_score_hourly_17": 0,
#     "trending_score_hourly_16": 0,
#     "trending_score_hourly_19": 0,
#     "trending_score_daily_5": 0,
#     "trending_score_daily_6": 0,
#     "trending_score_daily_1": 0,
#     "lcc_sort": "QH-0155.00000000.B14 S95 1658",
#     "trending_score_daily_2": 1,
#     "trending_score_daily_3": 1,
#     "trending_score_daily_4": 0,
#     "subject_key": [
#         "early_works_to_1800",
#         "education",
#         "fiction",
#         "fiction_city_life",
#         "fiction_classics",
#         "fiction_general",
#         "fiction_historical_general",
#         "natural_history",
#         "nonfiction",
#         "philosophy",
#         "philosophy_of_nature",
#         "political_science",
#         "pre-linnean_works",
#         "science",
#         "short_stories",
#         "the_state",
#         "utopias"
#     ],
#     "publisher_facet": [
#         "Adamant Media Corporation",
#         "Alfa Yayincilik",
#         "Book Jungle",
#         "Bottom of the Hill Publishing",
#         "Clarendon Press",
#         "Colombo",
#         "CreateSpace Independent Publishing Platform",
#         "Createspace Independent Publishing Platform",
#         "Discovery Publisher",
#         "Dodo Press",
#         "Dorlion Yayinevi",
#         "Dover Publications",
#         "Editorial Losada, s.a.",
#         "FQ Classics",
#         "Flammarion",
#         "Franklin Classics",
#         "Franklin Classics Trade Press",
#         "Haldeman-Julius Co.",
#         "IDB Productions",
#         "Independently Published",
#         "Independently published",
#         "Information Age Publishing, Incorporated",
#         "Izd-vo Akademii nauk SSSR",
#         "J. Crooke",
#         "J. Musier",
#         "Kabalci Yayinevi",
#         "Kessinger",
#         "Kessinger Publishing",
#         "Lulu.com",
#         "NuVision Publications",
#         "Open Road Integrated Media, Inc.",
#         "Oxford University Press",
#         "Philosophical Research Society",
#         "Printed by J. Haviland for W. Lee",
#         "Printed by J. Haviland, for W. Lee",
#         "Printed by J.F. and S.G. for William Lee ...",
#         "Printed by J.H. for William Lee ...",
#         "Printed by John Haviland for William Lee ...",
#         "Printed by John Haviland for William Lee and are to be sold by Iohn Williams",
#         "Printed by Tho. Newcomb",
#         "Printed for John Crooke ...",
#         "ReadHowYouWant.com",
#         "Reclam-Verlag",
#         "Say Yayinlari",
#         "Sine nomine",
#         "Start Publishing LLC",
#         "Stonewell Press",
#         "The Editorium, LLC",
#         "The Floating Press",
#         "Univ.Tut.P.",
#         "University Press",
#         "University of Cambridge ESOL Examinations",
#         "Zeplin Kitap",
#         "eBooksLib"
#     ],
#     "trending_score_hourly_22": 0,
#     "trending_score_hourly_23": 0,
#     "trending_score_hourly_1": 0,
#     "trending_score_hourly_2": 0,
#     "trending_score_hourly_3": 0,
#     "trending_score_hourly_5": 0,
#     "trending_score_hourly_6": 1,
#     "trending_score_hourly_7": 0,
#     "trending_score_hourly_8": 0,
#     "trending_score_hourly_9": 0,
#     "subject_facet": [
#         "Early works to 1800",
#         "Education",
#         "Fiction",
#         "Fiction, city life",
#         "Fiction, classics",
#         "Fiction, general",
#         "Fiction, historical, general",
#         "Natural history",
#         "Nonfiction",
#         "Philosophy",
#         "Philosophy of nature",
#         "Political science",
#         "Pre-Linnean works",
#         "Science",
#         "Short Stories",
#         "The State",
#         "Utopias"
#     ],
#     "_version_": 1844037969747378178,
#     "trending_z_score": 0.0,
#     "author_facet": [
#         "OL23720A Francis Bacon"
#     ],
#     "trending_score_hourly_sum": 1,
#     "ddc_sort": "335.02"
# }
# {
#     "author_alternative_name": [
#         "PETER CHARLETON"
#     ],
#     "author_key": [
#         "OL731358A"
#     ],
#     "author_name": [
#         "Peter Charleton"
#     ],
#     "cover_edition_key": "OL12573036M",
#     "cover_i": 2988448,
#     "ebook_access": "no_ebook",
#     "ebook_count_i": 0,
#     "edition_count": 3,
#     "edition_key": [
#         "OL23407569M",
#         "OL12573036M",
#         "OL22742291M"
#     ],
#     "first_publish_year": 2006,
#     "format": [
#         "Paperback"
#     ],
#     "has_fulltext": false,
#     "isbn": [
#         "1842181017",
#         "9781842181010"
#     ],
#     "key": "/works/OL3985538W",
#     "language": [
#         "eng"
#     ],
#     "last_modified_i": 1726044624,
#     "lcc": [
#         "BJ-1401.00000000.C43 2006"
#     ],
#     "lccn": [
#         "2006494105"
#     ],
#     "number_of_pages_median": 304,
#     "oclc": [
#         "72144291"
#     ],
#     "public_scan_b": false,
#     "publish_date": [
#         "31, May, 2006",
#         "2006"
#     ],
#     "publish_place": [
#         "DUBLIN"
#     ],
#     "publish_year": [
#         2006
#     ],
#     "publisher": [
#         "BLACKHALL PUBLISHING",
#         "Blackhall"
#     ],
#     "seed": [
#         "/books/OL23407569M",
#         "/books/OL12573036M",
#         "/books/OL22742291M",
#         "/works/OL3985538W",
#         "/authors/OL731358A",
#         "/subjects/good_and_evil",
#         "/subjects/deception"
#     ],
#     "title": "Lies In a Mirror",
#     "title_suggest": "Lies In a Mirror",
#     "title_sort": "Lies In a Mirror",
#     "type": "work",
#     "id_goodreads": [
#         "3090873",
#         "3090873"
#     ],
#     "subject": [
#         "Good and evil",
#         "Deception"
#     ],
#     "ratings_count_1": 1,
#     "ratings_count_2": 0,
#     "ratings_count_3": 0,
#     "ratings_count_4": 1,
#     "ratings_count_5": 1,
#     "ratings_average": 3.3333333,
#     "ratings_sortable": 2.280186,
#     "ratings_count": 3,
#     "readinglog_count": 94,
#     "want_to_read_count": 85,
#     "currently_reading_count": 6,
#     "already_read_count": 3,
#     "first_sentence": [
#         "There is a lie behind every crime. In order to cheat people of their money, fraudsters first dispossess them of their prudence by lying to them. Greed does the rest. When someone goes out to rape or kill another person, they will ensure that their victim is disarmed into a false sense of security by pretending, up to the critical moment, that they mean no harm.",
#         "Lies in a Mirror \r\nChapter 1\r\n\r\nThe Dynamic of Evil\r\n\r\n\r\nThere is a lie behind every crime. In order to cheat people of their money, fraudsters first dispossess them of their prudence by lying to them. Greed does the rest. When someone goes out to rape or kill another person, they will ensure that their victim is disarmed into a false sense of security by pretending, up to the critical moment, that they mean no harm. \r\n\r\nChapter 10\r\n\r\nHe Was Nothing\r\n\r\n\r\nWithin a few years of defending MD, the \u2018respectable\u2019 schoolteacher whose double life troubled me, I began prosecuting cases of sexual abuse: meeting the victims of incest, rape and childhood sexual abuse. No amount of study equips you for that experience. The victims are entitled to expect that the lawyer who undertakes the prosecution will pursue the case efficiently. That, however, is not all. They are hurt at the deepest level by their experience. They constantly query why their lives have been fractured. The advocate appearing for the State, they believe, should have some of the answers. I did not have any. But, no one could heartlessly brush people away by claiming that a lawyer\u2019s function is clinical and that he or she has no capacity to deal with hurt. Perhaps the least that you could do was to listen. \r\n\r\nIn those early days, before the courts began to order victim impact reports, time spent listening could be justified on the basis that it enabled you later, in open court, to ask the right questions in order to explain how they had suffered at the hands of the accused. Some victims hated their abuser. Strangely, these were very few. Of those subjected to sexual abuse, it was most often the parents of abused children who insisted that they wanted the perpetrator dead or spoke of him in demonic terms. The victims who suffered directly almost never said anything like that. They had other things to say. None of it was fantastic, or fanciful. Instead, it made sense. They reported what had happened to them. They spoke about the nature of their abuser coldly. Those who encounter murderers rarely live. I have met very few; only a couple of survivors of isolated rural robbery murders where another person was chosen for \u2018interrogation\u2019. The victims of sexual attacks are rarely killed, particularly within the home or institution where they are preyed upon. Their tormentor wants them to be available for the next time. Even more than the subjects of torture, those used for criminal sexual gratification get to know the whole person of their abuser. They see him in all of his colours and not just when he is energised by negativity. They have stared evil in the face and survived. Does that experience give them any understanding of the inner quality of the people who serve it?\r\n\r\nIn RG, one of the first of those cases, a builder had stayed from time to time with the same handful of families in a town in the west of Ireland. The men of those houses were in the same line of work as him and needed him on various jobs. Over years, he had abused a succession of the daughters of these households. He picked his opportunities late at night or by returning to the house he was staying in at a time when he might find a girl alone. Those who he had molested had suffered dreadfully. When the word came that the accused was going to plead guilty, I spoke to each of them individually. What, most of all, they wanted me to make the judge understand was that the abuser was nothing. It was a startling statement. At the time, I thought of this as an emotional response to a dreadful experience. I was wrong. A succession of cases over the years, criminal and civil, showed the same pattern. These victims had no emotion for the accused because, as many put it, he was \u201cnot worth it.\u201d As we say in this country, he was \u201ca waste of space.\u201d If they felt anything about him at all, they claimed it was pity, because he was \u201c ...
#         "There is a lie behind every crime."
#     ],
#     "trending_score_hourly_11": 0,
#     "trending_score_hourly_10": 0,
#     "trending_score_hourly_13": 0,
#     "trending_score_hourly_12": 0,
#     "trending_score_hourly_15": 0,
#     "trending_score_hourly_14": 0,
#     "trending_score_hourly_17": 0,
#     "trending_score_hourly_16": 0,
#     "trending_score_hourly_19": 0,
#     "trending_score_daily_5": 0,
#     "trending_score_daily_6": 1,
#     "trending_score_daily_1": 0,
#     "lcc_sort": "BJ-1401.00000000.C43 2006",
#     "trending_score_daily_2": 0,
#     "trending_score_daily_3": 1,
#     "trending_score_daily_4": 0,
#     "subject_key": [
#         "deception",
#         "good_and_evil"
#     ],
#     "trending_score_daily_0": 1,
#     "trending_score_hourly_20": 0,
#     "publisher_facet": [
#         "BLACKHALL PUBLISHING",
#         "Blackhall"
#     ],
#     "trending_score_hourly_22": 0,
#     "trending_score_hourly_21": 0,
#     "trending_score_hourly_1": 0,
#     "trending_score_hourly_2": 0,
#     "trending_score_hourly_3": 0,
#     "trending_score_hourly_4": 0,
#     "trending_score_hourly_5": 0,
#     "trending_score_hourly_6": 0,
#     "trending_score_hourly_7": 0,
#     "trending_score_hourly_8": 0,
#     "trending_score_hourly_9": 0,
#     "subject_facet": [
#         "Deception",
#         "Good and evil"
#     ],
#     "_version_": 1844000588288753664,
#     "trending_z_score": 0.0,
#     "author_facet": [
#         "OL731358A Peter Charleton"
#     ],
#     "trending_score_hourly_sum": 0
# }

# %% [markdown]
# ## checking missing titles against data dump
#
# The titles for which there are not matching records, check if we can find a near match.
#
# - TO DO: define near match.
# - TO DO: for titles with matches, check if author names have near matches as well

# %%
from unidecode import unidecode

from fuzzy_search.tokenization.token import Tokenizer


def normalise_string(text_string: str):
    if text_string is None or pd.isna(text_string):
        return ''
    text_string = unidecode(text_string)
    tokens = tokenizer.tokenize(text_string)
    return ' '.join([token.n for token in tokens])


def is_flex_match_doc(answer_title, answer_author, doc):
    doc_title = normalise_string(doc['title'])
    has_match = False
    try:
        doc_authors = get_oa_authors(doc, )
    except AttributeError:
        print(doc['author_name'])
        raise
    if answer_author is not None and len(doc_authors) > 0:
        return any(is_flex_match(answer_author, doc_author) for doc_author in doc_authors)
    return is_flex_match(answer_title, doc_title)


def get_oa_titles(record, response_field):
    return [normalise_string(doc['title']) for doc in record[response_field]['docs']]


def get_oa_authors(doc, normalise: bool = True):
    if 'author_name' not in doc:
        return []
    if normalise is True:
        return [normalise_string(author) for author in doc['author_name']]
    else:
        return [author for author in doc['author_name']]


def is_flex_match(answer_string, oa_string):
    return answer_string == oa_string or answer_string in oa_string or oa_string in answer_string


def get_flex_match_doc(record, response_field):
    answer_title = normalise_string(record['answer'])
    answer_author = normalise_string(record['author'])
    for doc in record[response_field]['docs']:
        if is_flex_match_doc(answer_title, answer_author, doc):
            return doc
    #print("unclear match:", answer_title, oa_titles)
    #print(answer_author, oa_authors)
    return None

# %% [markdown]
# For each record we extract three variables:
#
# 1. `readinglog_count` to indicate book item popularity
# 2. `first_publish_year` to indicate book recency
# 3. book genre and genre popularity

# %%
response_field = 'response_qta'
record = records[0]
no_match = 0
tokenizer = Tokenizer(ignorecase=True, remove_punctuation=True)

readinglog_rows = []
genre_rows = []
for ri, record in enumerate(records):
    if record[response_field]['num_found'] == 0:
        response_field = 'response_q'
    if record[response_field]['num_found'] == 0:
        continue
    doc = get_flex_match_doc(record, response_field)
    if doc is not None:
        readinglog_count = doc['readinglog_count'] if 'readinglog_count' in doc else 0
        answer_id = f"https://openlibrary.org{doc['key']}"
        doc_title = doc['title']
        first_publish_year = doc['first_publish_year'] if 'first_publish_year' in doc else None
        doc_author = '; '.join(get_oa_authors(doc, normalise=False))
        #print(json.dumps(doc, indent=4))
        #break
    else:
        readinglog_count = 0
        answer_id = None
        doc_title = None
        doc_author = None
        first_publish_year = None
        no_match += 1
        print(f"no match {no_match}: record num {ri}\treadinglog_count: {readinglog_count}")
    genre = thread_genre[record['thread_id']]
    genre_pop = genre_lists[genre] if genre in genre_lists else None
    row = [
        ri, record['thread_id'], record['answer'], record['author'], 
        answer_id, doc_title, doc_author, readinglog_count, first_publish_year,
        genre, genre_pop
    ]
    expected_rows = 11
    if len(row) > expected_rows:
        print(f"row has {len(row)} rows instead of {expected_rows}")
        print(row)
        break
    readinglog_rows.append(row)
# Out:
# no match 1: record num 12	readinglog_count: 0
# no match 2: record num 16	readinglog_count: 0
# no match 3: record num 25	readinglog_count: 0
# no match 4: record num 41	readinglog_count: 0
# no match 5: record num 59	readinglog_count: 0
# no match 6: record num 96	readinglog_count: 0
# no match 7: record num 129	readinglog_count: 0
# no match 8: record num 161	readinglog_count: 0
# no match 9: record num 165	readinglog_count: 0
# no match 10: record num 200	readinglog_count: 0
# no match 11: record num 212	readinglog_count: 0
# no match 12: record num 265	readinglog_count: 0
# no match 13: record num 287	readinglog_count: 0
# no match 14: record num 289	readinglog_count: 0
# no match 15: record num 305	readinglog_count: 0
# no match 16: record num 362	readinglog_count: 0
# no match 17: record num 372	readinglog_count: 0
# no match 18: record num 374	readinglog_count: 0
# no match 19: record num 382	readinglog_count: 0
# no match 20: record num 422	readinglog_count: 0
# no match 21: record num 429	readinglog_count: 0
# no match 22: record num 443	readinglog_count: 0
# no match 23: record num 455	readinglog_count: 0
# no match 24: record num 464	readinglog_count: 0
# no match 25: record num 471	readinglog_count: 0
# no match 26: record num 511	readinglog_count: 0
# no match 27: record num 539	readinglog_count: 0
# no match 28: record num 541	readinglog_count: 0
# no match 29: record num 619	readinglog_count: 0
# no match 30: record num 644	readinglog_count: 0
# no match 31: record num 674	readinglog_count: 0
# no match 32: record num 761	readinglog_count: 0
# no match 33: record num 798	readinglog_count: 0
# no match 34: record num 881	readinglog_count: 0
# no match 35: record num 911	readinglog_count: 0
# no match 36: record num 920	readinglog_count: 0
# no match 37: record num 960	readinglog_count: 0
# no match 38: record num 970	readinglog_count: 0
# no match 39: record num 1032	readinglog_count: 0
# no match 40: record num 1063	readinglog_count: 0
# no match 41: record num 1070	readinglog_count: 0
# no match 42: record num 1099	readinglog_count: 0
# no match 43: record num 1144	readinglog_count: 0
# no match 44: record num 1155	readinglog_count: 0
# no match 45: record num 1167	readinglog_count: 0
# no match 46: record num 1174	readinglog_count: 0
# no match 47: record num 1216	readinglog_count: 0
# no match 48: record num 1306	readinglog_count: 0
# no match 49: record num 1308	readinglog_count: 0
# no match 50: record num 1329	readinglog_count: 0
# no match 51: record num 1370	readinglog_count: 0
# no match 52: record num 1392	readinglog_count: 0
# no match 53: record num 1400	readinglog_count: 0
# no match 54: record num 1443	readinglog_count: 0
# no match 55: record num 1449	readinglog_count: 0
# no match 56: record num 1463	readinglog_count: 0
# no match 57: record num 1464	readinglog_count: 0
# no match 58: record num 1473	readinglog_count: 0

# %%
readinglog_rows[0]
# Out:
# [0,
#  '13195',
#  'Lovey: A Very Special Child',
#  'Mary MacCracken',
#  'https://openlibrary.org/works/OL5262888W',
#  'Lovey',
#  'Mary MacCracken',
#  4,
#  1977]

# %% [markdown]
# Finally, we write all book feature data to file:

# %%
readinglog_cols = [
    'req_no', 'thread_id', 'answer_title', 'answer_author',
    'work_id', 'work_title','work_author', 'readinglog_count', 'first_publish_year',
    'genre', 'genre_popularity'
]
readinglog_df = pd.DataFrame(readinglog_rows, columns=readinglog_cols)
readinglog_df
# Out:
#       req_no thread_id                                       answer_title  \
# 0          0     13195                        Lovey: A Very Special Child
# 1          1     14207                                      Clone Catcher
# 2          2     37787  The Hite Report: A Nationwide Study of Female ...
# 3          5    160509                            Against Incredible Odds
# 4          6    178121    Donbas: A True Story of an Escape Across Russia
# ...      ...       ...                                                ...
# 1410    1476  23187261                                 A Touch of Shadows
# 1411    1477  23187967                                              Ariel
# 1412    1478  23190385                       The Young Traveler in Sweden
# 1413    1479  23190983                                Visions of Darkness
# 1414    1480  23191999                              But Then I Came Back
#
#            answer_author                                    work_id  \
# 0        Mary MacCracken   https://openlibrary.org/works/OL5262888W
# 1           Alfred Slote  https://openlibrary.org/works/OL15926986W
# 2                    NaN   https://openlibrary.org/works/OL2815101W
# 3            Arthur Roth  https://openlibrary.org/works/OL16478118W
# 4     Jacques Sandulescu   https://openlibrary.org/works/OL7003295W
# ...                  ...                                        ...
# 1410      Jessica Thorne  https://openlibrary.org/works/OL42425465W
# 1411    Steven R. Boyett   https://openlibrary.org/works/OL1876345W
# 1412   George L. Proctor   https://openlibrary.org/works/OL6939723W
# 1413                 NaN     https://openlibrary.org/works/OL17732W
# 1414                 NaN  https://openlibrary.org/works/OL19354389W
#
#                         work_title         work_author  readinglog_count  \
# 0                            Lovey     Mary MacCracken                 4
# 1                    Clone catcher        Alfred Slote                 9
# 2         Hite Report Women & Love          Shere Hite                34
# 3          Against incredible odds                                     0
# 4                           Donbas  Jacques Sandulescu                 2
# ...                            ...                 ...               ...
# 1410              Touch of Shadows      Jessica Thorne                 0
# 1411                         Ariel    Steven R. Boyett                11
# 1412  The young traveler in Sweden   George L. Proctor                 0
# 1413                         Bible               Bible              1999
# 1414          But Then I Came Back       Estelle Laure                 4
#
#       first_publish_year        genre  genre_popularity
# 0                 1977.0         None               NaN
# 1                 1982.0  Young Adult            5880.0
# 2                 1976.0      Fiction            7764.0
# 3                 1983.0         None               NaN
# 4                 1968.0         None               NaN
# ...                  ...          ...               ...
# 1410              2025.0      Fantasy            5348.0
# 1411              1984.0      Fantasy            5348.0
# 1412              1953.0   Children's            2526.0
# 1413              1200.0      Fantasy            5348.0
# 1414              2017.0  Young Adult            5880.0
#
# [1415 rows x 11 columns]

# %%
readinglog_df.to_csv('../../data/books/book_answers-popularity.tsv', sep='\t', index=False)

# %%
readinglog_df.readinglog_count.value_counts()
# Out:
# readinglog_count
# 0       381
# 1       159
# 2       112
# 3        62
# 4        58
#        ...
# 2692      1
# 1919      1
# 108       1
# 4478      1
# 314       1
# Name: count, Length: 223, dtype: int64
