# %% [markdown]
# # Zero-shot KI retrieval workflow (OpenAI)
#
# First load the required libraries (including the OpenAI API) and initialize relevant variables.

# %%
import os
import sys
import numpy as np
import pandas as pd
from pprint import pprint 
from openai import OpenAI
from textwrap import wrap
from time import localtime, strftime, sleep

# # Initalize our OpenAI key.
# api_key_file = "/Users/tobo/Work/Experiments/DS-tryouts/openai-api-key.txt"
# with open(api_key_file, 'r') as f:
#     for line in f:
#         api_key = line.strip()
#         break

# Initialize variables.
N = 20   # Number of results to return
K = 3    # Number of times to run the same prompt

# %% [markdown]
# The function below takes a file containing first posts, converts them into the right prompts and runs them against the OpenAI API using the specified model.

# %%
# Define a function that takes all the first posts, converts them into the right prompts 
# and runs them against the OpenAI API using the specified model. Threads already processed
# will be skipped. By default the method prints out its progress, but this can be disabled 
# by setting the 'silent' parameter to 'True'.
def process_first_posts(first_posts_file, model, silent=False):

    # Extract the metadata from the filename.
    (temp1, data_type, domain, source, extension) = first_posts_file.split(".")
    domain_singular = domain[0:len(domain) - 1]
    metadata_string = f"{model}.{domain}.{data_type}.{source}"


    # Print out the selected model.
    if (silent == False):
        now = strftime("%Y-%m-%d %H:%M:%S", localtime())
        print(f"{now}\tRunning against OpenAI API ({metadata_string})")


    # Read in all first posts from file into a Pandas dataframe. Then extract a list of all thread IDs to crawl.
    all_posts = pd.read_table(first_posts_file, header = 0)
    thread_id_list = all_posts['thread_id'].tolist()


    # Where are we going to save the API responses? Make sure this results directory exists before saving to it.
    results_dir_path = os.path.join(os.getcwd(), metadata_string)
    if not os.path.exists(results_dir_path):
        if (silent == False):
            now = strftime("%Y-%m-%d %H:%M:%S", localtime())
            print(f"{now}\t{results_dir_path} does not exist!")
        os.makedirs(results_dir_path)


    # For each publication, find the citing documents and collect all the publication metadata.
    for thread_id in thread_id_list:
    # for thread_id in thread_id_list[0:5]:

        # Extract the raw post text.
        request = all_posts.loc[all_posts['thread_id'] == thread_id, 'request'].item()

        # Create the appropriate prompt.
        prompt_start = f"Identify the {domain_singular} the user is looking for as described in the request below:"
        prompt_middle = f"Request: \"{request}\""
        prompt_end = f"Please provide a ranked list of your {N} best guesses for the correct answer. Please answer in a JSON object that contains a ranked list of suggestions. Each suggestion should contain a field called 'answer' containing the suggestion (title and release year), a field 'explanation' containing an explanation of why these {domain_singular}s could be the correct answer, and a 'confidence' score that represents how confident you are of your suggestion."
        if (domain == "books"):
            prompt_end = f"Please provide a ranked list of your {N} best guesses for the correct answer. Please answer in a JSON object that contains a ranked list of suggestions. Each suggestion should contain a field called 'answer' containing the suggestion (title and author), a field 'explanation' containing an explanation of why these {domain_singular}s could be the correct answer, and a 'confidence' score that represents how confident you are of your suggestion."
        prompt_start = "\n".join(wrap(prompt_start))
        prompt_middle = "\n".join(wrap(prompt_middle))
        prompt_end = "\n".join(wrap(prompt_end))
        prompt_text = f"{prompt_start}\n\n{prompt_middle}\n\n{prompt_end}"

        # Save the prompt to file (so we can easily run it manually if we wish).
        prompt_file = os.path.join(results_dir_path, f"prompt.{thread_id}.txt")
        f = open(prompt_file, "w")
        f.write(prompt_text)
        f.close()

        # Have we already processed this one? If not, skip to the next one (just check the v1 of this).
        output_file = os.path.join(results_dir_path, f"{thread_id}.{model}.v1.json")
        now = strftime("%Y-%m-%d %H:%M:%S", localtime())
        if os.path.exists(output_file):
            if (silent == False):
                print(f"{now}\tAlready processed thread '{thread_id}'")
            continue
        else:
            
            # Run the prompt against OpenAI's API.
            sleep(1)
            if (silent == False):
                print(f"{now}\tProcessing of thread '{thread_id}'")
            client = OpenAI()
            completion = client.chat.completions.create(
                model=f"{model}",
                n=K,
                messages=[{"role": "user", "content": prompt_text}]
            )

            # Process the response(s) and save to file(s).
            no_of_responses = len(completion.choices)
            if (silent == False):
                now = strftime("%Y-%m-%d %H:%M:%S", localtime())
                print(f"{now}\t  * Saving {no_of_responses} responses to file")
            for k in range(0, no_of_responses):
                output_file = os.path.join(results_dir_path, f"{thread_id}.{model}.v{k+1}.json")
                if (silent == False):
                    print(f"{now}\t    - {thread_id}.v{k+1}.json")
                choice = completion.choices[k]        # Get the current response of K total responses
                response = choice.message             # Extract the full response message that OpenAI returned
                generated_answer = response.content   # Extract the actual JSON-formatted answer.
                
                # Remove the enclosing ```json and ``` lines.
                generated_answer = generated_answer.replace("```json", "")
                generated_answer = generated_answer.replace("```", "")

                # Save to file.
                f = open(output_file, "w")
                f.write(generated_answer)
                f.close()

# %%
# Which OpenAI model will we use?
# model = "gpt-4o"
model = "gpt-4o-mini"
# model = "gpt-4-turbo"
# model = "gpt-4"         # Note: does not answer the questions!
# model = "gpt-3.5-turbo"

# # Books - JDoc annotated - LibraryThing
# first_posts_file = "first-posts.jdoc-annotated.books.librarything.tsv"
# process_first_posts(first_posts_file, model)

# # Games - JDoc annotated - Reddit
# first_posts_file = "first-posts.jdoc-annotated.games.reddit.tsv"
# process_first_posts(first_posts_file, model)

# # Movies - JDoc annotated - IMDB
# first_posts_file = "first-posts.jdoc-annotated.movies.imdb.tsv"
# process_first_posts(first_posts_file, model)

# # Books - Extra - Reddit
# first_posts_file = "first-posts.extra.books.reddit.tsv"
# process_first_posts(first_posts_file, model)

# # Games - Extra - Reddit
# first_posts_file = "first-posts.extra.games.reddit.tsv"
# process_first_posts(first_posts_file, model)

# # Movies - Extra - IMDB
# first_posts_file = "first-posts.extra.movies.imdb.tsv"
# process_first_posts(first_posts_file, model)



# model = "gpt-4o"

# # Books - JDoc annotated - LibraryThing
# first_posts_file = "first-posts.jdoc-annotated.books.librarything.tsv"
# process_first_posts(first_posts_file, model)

# # Games - JDoc annotated - Reddit
# first_posts_file = "first-posts.jdoc-annotated.games.reddit.tsv"
# process_first_posts(first_posts_file, model)

# # Movies - JDoc annotated - IMDB
# first_posts_file = "first-posts.jdoc-annotated.movies.imdb.tsv"
# process_first_posts(first_posts_file, model)



model = "gpt-3.5-turbo"

# Books - JDoc annotated - LibraryThing
first_posts_file = "first-posts.jdoc-annotated.books.librarything.tsv"
process_first_posts(first_posts_file, model)

# Games - JDoc annotated - Reddit
first_posts_file = "first-posts.jdoc-annotated.games.reddit.tsv"
process_first_posts(first_posts_file, model)

# Movies - JDoc annotated - IMDB
first_posts_file = "first-posts.jdoc-annotated.movies.imdb.tsv"
process_first_posts(first_posts_file, model)

# Books - Extra - Reddit
first_posts_file = "first-posts.extra.books.reddit.tsv"
process_first_posts(first_posts_file, model)

# Games - Extra - Reddit
first_posts_file = "first-posts.extra.games.reddit.tsv"
process_first_posts(first_posts_file, model)

# Movies - Extra - IMDB
first_posts_file = "first-posts.extra.movies.imdb.tsv"
process_first_posts(first_posts_file, model)
# Out:
# 2024-10-11 20:53:28	Running against OpenAI API (gpt-3.5-turbo.books.jdoc-annotated.librarything)
# 2024-10-11 20:53:28	Already processed thread '127931'
# 2024-10-11 20:53:28	Already processed thread '57827'
# 2024-10-11 20:53:28	Already processed thread '20772'
# 2024-10-11 20:53:28	Already processed thread '41717'
# 2024-10-11 20:53:29	Already processed thread '113809'
# 2024-10-11 20:53:29	Already processed thread '20193'
# 2024-10-11 20:53:29	Already processed thread '68922'
# 2024-10-11 20:53:29	Already processed thread '129136'
# 2024-10-11 20:53:29	Already processed thread '21768'
# 2024-10-11 20:53:29	Already processed thread '3861'
# 2024-10-11 20:53:29	Already processed thread '114836'
# 2024-10-11 20:53:29	Already processed thread '42904'
# 2024-10-11 20:53:29	Already processed thread '111795'
# 2024-10-11 20:53:29	Already processed thread '88491'
# 2024-10-11 20:53:29	Already processed thread '93190'
# 2024-10-11 20:53:29	Already processed thread '50119'
# 2024-10-11 20:53:29	Already processed thread '101634'
# 2024-10-11 20:53:29	Already processed thread '73205'
# 2024-10-11 20:53:29	Already processed thread '100990'
# 2024-10-11 20:53:29	Already processed thread '115815'
# 2024-10-11 20:53:29	Already processed thread '72921'
# 2024-10-11 20:53:29	Already processed thread '63477'
# 2024-10-11 20:53:29	Already processed thread '45761'
# 2024-10-11 20:53:29	Already processed thread '115749'
# 2024-10-11 20:53:29	Already processed thread '109530'
# 2024-10-11 20:53:29	Already processed thread '53741'
# 2024-10-11 20:53:29	Already processed thread '88811'
# 2024-10-11 20:53:29	Already processed thread '22268'
# 2024-10-11 20:53:29	Already processed thread '125091'
# 2024-10-11 20:53:29	Already processed thread '22246'
# 2024-10-11 20:53:29	Already processed thread '94761'
# 2024-10-11 20:53:29	Already processed thread '27705'
# 2024-10-11 20:53:29	Already processed thread '64668'
# 2024-10-11 20:53:29	Already processed thread '64846'
# 2024-10-11 20:53:29	Already processed thread '115019'
# 2024-10-11 20:53:29	Already processed thread '111989'
# 2024-10-11 20:53:29	Already processed thread '101356'
# 2024-10-11 20:53:29	Already processed thread '79774'
# 2024-10-11 20:53:29	Already processed thread '119306'
# 2024-10-11 20:53:29	Already processed thread '27625'
# 2024-10-11 20:53:29	Already processed thread '113543'
# 2024-10-11 20:53:29	Already processed thread '92996'
# 2024-10-11 20:53:29	Already processed thread '74255'
# 2024-10-11 20:53:29	Already processed thread '103678'
# 2024-10-11 20:53:29	Already processed thread '116403'
# 2024-10-11 20:53:30	Already processed thread '8rq9xm'
# 2024-10-11 20:53:30	Already processed thread '8rqxxe'
# 2024-10-11 20:53:30	Already processed thread '8rrx13'
# 2024-10-11 20:53:30	Already processed thread '8rsie0'
# 2024-10-11 20:53:30	Already processed thread '8rt8id'
# 2024-10-11 20:53:30	Already processed thread '8rtd7t'
# 2024-10-11 20:53:30	Already processed thread '8rubrw'
# 2024-10-11 20:53:30	Already processed thread '8rur8s'
# 2024-10-11 20:53:30	Already processed thread '8rvgdc'
# 2024-10-11 20:53:30	Already processed thread '8rwrz0'
# 2024-10-11 20:53:30	Already processed thread '8rzp6z'
# 2024-10-11 20:53:30	Already processed thread '8s0obx'
# 2024-10-11 20:53:30	Already processed thread '8s25ba'
# 2024-10-11 20:53:30	Already processed thread '8s3zg9'
# 2024-10-11 20:53:30	Already processed thread '8s4dd0'
# 2024-10-11 20:53:30	Already processed thread '8s4gc0'
# 2024-10-11 20:53:30	Already processed thread '8s5jal'
# 2024-10-11 20:53:30	Already processed thread '8s7n7p'
# 2024-10-11 20:53:30	Already processed thread '8sav2b'
# 2024-10-11 20:53:30	Already processed thread '8sb40j'
# 2024-10-11 20:53:30	Already processed thread '8sbhst'
# 2024-10-11 20:53:30	Already processed thread '8sc4ij'
# 2024-10-11 20:53:30	Already processed thread '8sg1jo'
# 2024-10-11 20:53:30	Already processed thread '8shj8h'
# 2024-10-11 20:53:30	Already processed thread '8sj5ow'
# 2024-10-11 20:53:30	Already processed thread '8sj8s5'
# 2024-10-11 20:53:30	Already processed thread '8slod7'
# 2024-10-11 20:53:30	Already processed thread '8slz92'
# 2024-10-11 20:53:30	Already processed thread '8smdbt'
# 2024-10-11 20:53:30	Already processed thread '8sn0qn'
# 2024-10-11 20:53:30	Already processed thread '8snaa9'
# 2024-10-11 20:53:30	Already processed thread '8somww'
# 2024-10-11 20:53:30	Already processed thread '8spglh'
# 2024-10-11 20:53:30	Already processed thread '8spls1'
# 2024-10-11 20:53:30	Already processed thread '8spyiw'
# 2024-10-11 20:53:30	Already processed thread '8sr4qj'
# 2024-10-11 20:53:30	Already processed thread '8stqxk'
# 2024-10-11 20:53:30	Already processed thread '8sxbby'
# 2024-10-11 20:53:30	Already processed thread '8sxbek'
# 2024-10-11 20:53:30	Already processed thread '8sykrr'
# 2024-10-11 20:53:30	Running against OpenAI API (gpt-3.5-turbo.games.extra.reddit)
# 2024-10-11 20:53:30	Already processed thread '8nnqop'
# 2024-10-11 20:53:30	Already processed thread '8nows7'
# 2024-10-11 20:53:30	Already processed thread '8npw3z'
# 2024-10-11 20:53:30	Already processed thread '8nq6my'
# 2024-10-11 20:53:30	Already processed thread '8nqfie'
# 2024-10-11 20:53:30	Already processed thread '8nqg9k'
# 2024-10-11 20:53:30	Already processed thread '8nqgal'
# 2024-10-11 20:53:30	Already processed thread '8nqpt8'
# 2024-10-11 20:53:30	Already processed thread '8nqsym'
# 2024-10-11 20:53:30	Already processed thread '8nrt8a'
# 2024-10-11 20:53:30	Already processed thread '8nsjug'
# 2024-10-11 20:53:30	Already processed thread '8nsx8x'
# 2024-10-11 20:53:30	Already processed thread '8nsyww'
# 2024-10-11 20:53:30	Already processed thread '8nt66u'
# 2024-10-11 20:53:30	Already processed thread '8ntnzb'
# 2024-10-11 20:53:30	Already processed thread '8ntnzj'
# 2024-10-11 20:53:30	Already processed thread '8nuib2'
# 2024-10-11 20:53:30	Already processed thread '8nv5bk'
# 2024-10-11 20:53:30	Already processed thread '8nv5is'
# 2024-10-11 20:53:30	Already processed thread '8nvdf8'
# 2024-10-11 20:53:30	Already processed thread '8nvh00'
# 2024-10-11 20:53:30	Already processed thread '8nvuuz'
# 2024-10-11 20:53:30	Already processed thread '8nxe49'
# 2024-10-11 20:53:30	Already processed thread '8ny0rv'
# 2024-10-11 20:53:30	Already processed thread '8nyhtg'
# 2024-10-11 20:53:30	Already processed thread '8nym2j'
# 2024-10-11 20:53:30	Already processed thread '8nypcp'
# 2024-10-11 20:53:30	Already processed thread '8nzotx'
# 2024-10-11 20:53:30	Already processed thread '8o0ch8'
# 2024-10-11 20:53:30	Already processed thread '8o0hj0'
# 2024-10-11 20:53:31	Already processed thread '8o0tyf'
# 2024-10-11 20:53:31	Already processed thread '8o1ff4'
# 2024-10-11 20:53:31	Already processed thread '8o1hrz'
# 2024-10-11 20:53:31	Already processed thread '8o1psm'
# 2024-10-11 20:53:31	Already processed thread '8o1x39'
# 2024-10-11 20:53:31	Already processed thread '8o3goi'
# 2024-10-11 20:53:31	Already processed thread '8o4bm2'
# 2024-10-11 20:53:31	Already processed thread '8o4uu5'
# 2024-10-11 20:53:31	Already processed thread '8o5hb5'
# 2024-10-11 20:53:31	Already processed thread '8o5w8d'
# 2024-10-11 20:53:31	Already processed thread '8o6ado'
# 2024-10-11 20:53:31	Already processed thread '8o6yhc'
# 2024-10-11 20:53:31	Already processed thread '8o7px5'
# 2024-10-11 20:53:31	Already processed thread '8o7tsp'
# 2024-10-11 20:53:31	Already processed thread '8o7um7'
# 2024-10-11 20:53:31	Already processed thread '8o7w4s'
# 2024-10-11 20:53:31	Already processed thread '8o7y1j'
# 2024-10-11 20:53:31	Already processed thread '8o7y2f'
# 2024-10-11 20:53:31	Already processed thread '8o8l7r'
# 2024-10-11 20:53:31	Already processed thread '8o8lka'
# 2024-10-11 20:53:31	Already processed thread '8o9yy8'
# 2024-10-11 20:53:31	Already processed thread '8o17oi'
# 2024-10-11 20:53:31	Already processed thread '8o21vk'
# 2024-10-11 20:53:31	Already processed thread '8o39zm'
# 2024-10-11 20:53:31	Already processed thread '8o56p1'
# 2024-10-11 20:53:31	Already processed thread '8o56qm'
# 2024-10-11 20:53:31	Already processed thread '8o62j1'
# 2024-10-11 20:53:31	Already processed thread '8o79qq'
# 2024-10-11 20:53:31	Already processed thread '8o81sf'
# 2024-10-11 20:53:31	Already processed thread '8o92qu'
# 2024-10-11 20:53:31	Already processed thread '8o794k'
# 2024-10-11 20:53:31	Already processed thread '8o848p'
# 2024-10-11 20:53:31	Already processed thread '8oanrp'
# 2024-10-11 20:53:31	Already processed thread '8ob4gp'
# 2024-10-11 20:53:31	Already processed thread '8ob4qp'
# 2024-10-11 20:53:31	Already processed thread '8obe4c'
# 2024-10-11 20:53:31	Already processed thread '8obken'
# 2024-10-11 20:53:31	Already processed thread '8oc3qi'
# 2024-10-11 20:53:31	Already processed thread '8oc57k'
# 2024-10-11 20:53:31	Already processed thread '8oci7n'
# 2024-10-11 20:53:31	Already processed thread '8od0on'
# 2024-10-11 20:53:31	Already processed thread '8odca6'
# 2024-10-11 20:53:31	Already processed thread '8odlh5'
# 2024-10-11 20:53:31	Already processed thread '8odomd'
# 2024-10-11 20:53:31	Already processed thread '8odtt0'
# 2024-10-11 20:53:31	Already processed thread '8odvod'
# 2024-10-11 20:53:31	Already processed thread '8oegpk'
# 2024-10-11 20:53:31	Already processed thread '8oemoa'
# 2024-10-11 20:53:31	Already processed thread '8of7tk'
# 2024-10-11 20:53:31	Already processed thread '8ofa0z'
# 2024-10-11 20:53:31	Already processed thread '8ofar9'
# 2024-10-11 20:53:31	Already processed thread '8ofb13'
# 2024-10-11 20:53:31	Already processed thread '8ofdvd'
# 2024-10-11 20:53:31	Already processed thread '8ofr77'
# 2024-10-11 20:53:31	Already processed thread '8ofstx'
# 2024-10-11 20:53:31	Already processed thread '8ofval'
# 2024-10-11 20:53:31	Already processed thread '8og8je'
# 2024-10-11 20:53:31	Already processed thread '8ogoua'
# 2024-10-11 20:53:31	Already processed thread '8oh3ms'
# 2024-10-11 20:53:31	Already processed thread '8ohi8j'
# 2024-10-11 20:53:31	Already processed thread '8oibu1'
# 2024-10-11 20:53:31	Already processed thread '8oiby3'
# 2024-10-11 20:53:31	Already processed thread '8oizn8'
# 2024-10-11 20:53:31	Already processed thread '8okqu3'
# 2024-10-11 20:53:31	Already processed thread '8okxmj'
# 2024-10-11 20:53:31	Already processed thread '8ol8d9'
# 2024-10-11 20:53:31	Already processed thread '8olevh'
# 2024-10-11 20:53:31	Already processed thread '8olgz7'
# 2024-10-11 20:53:31	Already processed thread '8olsq5'
# 2024-10-11 20:53:31	Already processed thread '8om6q3'
# 2024-10-11 20:53:31	Already processed thread '8omt8s'
# 2024-10-11 20:53:31	Already processed thread '8omthg'
# 2024-10-11 20:53:31	Already processed thread '8on18a'
# 2024-10-11 20:53:31	Already processed thread '8onclh'
# 2024-10-11 20:53:31	Already processed thread '8ondkb'
# 2024-10-11 20:53:31	Already processed thread '8oomxj'
# 2024-10-11 20:53:31	Already processed thread '8ooo6s'
# 2024-10-11 20:53:31	Already processed thread '8oorfp'
# 2024-10-11 20:53:31	Already processed thread '8opj7d'
# 2024-10-11 20:53:31	Already processed thread '8oq5ij'
# 2024-10-11 20:53:31	Already processed thread '8oqk54'
# 2024-10-11 20:53:31	Already processed thread '8oqonj'
# 2024-10-11 20:53:31	Already processed thread '8oqws0'
# 2024-10-11 20:53:31	Already processed thread '8or6ta'
# 2024-10-11 20:53:31	Already processed thread '8ora5q'
# 2024-10-11 20:53:31	Already processed thread '8orlqp'
# 2024-10-11 20:53:31	Already processed thread '8os50j'
# 2024-10-11 20:53:31	Already processed thread '8osfyi'
# 2024-10-11 20:53:31	Already processed thread '8oslij'
# 2024-10-11 20:53:31	Already processed thread '8oslv8'
# 2024-10-11 20:53:31	Already processed thread '8osurw'
# 2024-10-11 20:53:31	Already processed thread '8osv3l'
# 2024-10-11 20:53:31	Already processed thread '8ot89d'
# 2024-10-11 20:53:31	Already processed thread '8ov7ak'
# 2024-10-11 20:53:31	Already processed thread '8ov66h'
# 2024-10-11 20:53:31	Already processed thread '8ovcbh'
# 2024-10-11 20:53:31	Already processed thread '8ovd8x'
# 2024-10-11 20:53:31	Already processed thread '8ovv8v'
# 2024-10-11 20:53:31	Already processed thread '8ovwa2'
# 2024-10-11 20:53:31	Already processed thread '8ow2i0'
# 2024-10-11 20:53:31	Already processed thread '8ow2kf'
# 2024-10-11 20:53:31	Already processed thread '8owxfy'
# 2024-10-11 20:53:31	Already processed thread '8ox4mn'
# 2024-10-11 20:53:31	Already processed thread '8ox8c1'
# 2024-10-11 20:53:31	Already processed thread '8ox74g'
# 2024-10-11 20:53:31	Already processed thread '8oxvuy'
# 2024-10-11 20:53:31	Already processed thread '8oxy02'
# 2024-10-11 20:53:31	Already processed thread '8oy4ls'
# 2024-10-11 20:53:31	Already processed thread '8oyxea'
# 2024-10-11 20:53:31	Already processed thread '8oz0od'
# 2024-10-11 20:53:31	Already processed thread '8oz1ny'
# 2024-10-11 20:53:31	Already processed thread '8p0h38'
# 2024-10-11 20:53:31	Already processed thread '8p0qq1'
# 2024-10-11 20:53:31	Already processed thread '8p1aks'
# 2024-10-11 20:53:31	Already processed thread '8p1dyu'
# 2024-10-11 20:53:31	Already processed thread '8p1glq'
# 2024-10-11 20:53:31	Already processed thread '8p2sw0'
# 2024-10-11 20:53:31	Already processed thread '8p3bcy'
# 2024-10-11 20:53:31	Already processed thread '8p3svp'
# 2024-10-11 20:53:31	Already processed thread '8p3yz6'
# 2024-10-11 20:53:31	Already processed thread '8p4bds'
# 2024-10-11 20:53:31	Already processed thread '8p4xw1'
# 2024-10-11 20:53:31	Already processed thread '8p5lcz'
# 2024-10-11 20:53:31	Already processed thread '8p5w87'
# 2024-10-11 20:53:31	Already processed thread '8p6bii'
# 2024-10-11 20:53:31	Already processed thread '8p6qn6'
# 2024-10-11 20:53:31	Already processed thread '8p6tsa'
# 2024-10-11 20:53:31	Already processed thread '8p7rw8'
# 2024-10-11 20:53:31	Already processed thread '8p9l1z'
# 2024-10-11 20:53:31	Already processed thread '8p40sq'
# 2024-10-11 20:53:31	Already processed thread '8p427b'
# 2024-10-11 20:53:31	Already processed thread '8p6985'
# 2024-10-11 20:53:31	Already processed thread '8patji'
# 2024-10-11 20:53:31	Already processed thread '8pbb37'
# 2024-10-11 20:53:31	Already processed thread '8pbhei'
# 2024-10-11 20:53:31	Already processed thread '8pc1r6'
# 2024-10-11 20:53:31	Already processed thread '8pc5q3'
# 2024-10-11 20:53:31	Already processed thread '8pc7c9'
# 2024-10-11 20:53:31	Already processed thread '8pdazg'
# 2024-10-11 20:53:31	Already processed thread '8pdl6f'
# 2024-10-11 20:53:31	Already processed thread '8pe08f'
# 2024-10-11 20:53:31	Already processed thread '8pead5'
# 2024-10-11 20:53:31	Already processed thread '8petyj'
# 2024-10-11 20:53:31	Already processed thread '8pf1pk'
# 2024-10-11 20:53:31	Already processed thread '8pfx9v'
# 2024-10-11 20:53:31	Already processed thread '8pg0nj'
# 2024-10-11 20:53:31	Already processed thread '8pg73t'
# 2024-10-11 20:53:31	Already processed thread '8pggx3'
# 2024-10-11 20:53:31	Already processed thread '8ph7gj'
# 2024-10-11 20:53:31	Already processed thread '8ph8fb'
# 2024-10-11 20:53:31	Already processed thread '8ph26b'
# 2024-10-11 20:53:31	Already processed thread '8phwpm'
# 2024-10-11 20:53:31	Already processed thread '8pi8qt'
# 2024-10-11 20:53:31	Already processed thread '8pitoa'
# 2024-10-11 20:53:31	Already processed thread '8pj3x5'
# 2024-10-11 20:53:31	Already processed thread '8pjnk5'
# 2024-10-11 20:53:31	Already processed thread '8pjpr9'
# 2024-10-11 20:53:31	Already processed thread '8pk5n1'
# 2024-10-11 20:53:31	Already processed thread '8pkt3t'
# 2024-10-11 20:53:31	Already processed thread '8pktfu'
# 2024-10-11 20:53:31	Already processed thread '8plwb4'
# 2024-10-11 20:53:31	Already processed thread '8pme88'
# 2024-10-11 20:53:31	Already processed thread '8pmszc'
# 2024-10-11 20:53:31	Already processed thread '8pnvnd'
# 2024-10-11 20:53:31	Already processed thread '8pnweu'
# 2024-10-11 20:53:31	Already processed thread '8poy94'
# 2024-10-11 20:53:31	Already processed thread '8ppfk3'
# 2024-10-11 20:53:31	Already processed thread '8ppuyh'
# 2024-10-11 20:53:31	Already processed thread '8ppv7k'
# 2024-10-11 20:53:31	Already processed thread '8pq2ps'
# 2024-10-11 20:53:31	Already processed thread '8pqat4'
# 2024-10-11 20:53:31	Already processed thread '8pr26f'
# 2024-10-11 20:53:31	Already processed thread '8praen'
# 2024-10-11 20:53:31	Already processed thread '8prgvx'
# 2024-10-11 20:53:31	Already processed thread '8prnld'
# 2024-10-11 20:53:31	Already processed thread '8prp11'
# 2024-10-11 20:53:31	Already processed thread '8prv1f'
# 2024-10-11 20:53:31	Already processed thread '8ps109'
# 2024-10-11 20:53:31	Already processed thread '8pshxo'
# 2024-10-11 20:53:31	Already processed thread '8pskg3'
# 2024-10-11 20:53:31	Already processed thread '8ptg7t'
# 2024-10-11 20:53:31	Already processed thread '8ptv8j'
# 2024-10-11 20:53:31	Already processed thread '8pu8sl'
# 2024-10-11 20:53:31	Already processed thread '8pugt1'
# 2024-10-11 20:53:31	Already processed thread '8pv4vu'
# 2024-10-11 20:53:31	Already processed thread '8pvhlj'
# 2024-10-11 20:53:31	Already processed thread '8pvnzi'
# 2024-10-11 20:53:31	Already processed thread '8pvtg7'
# 2024-10-11 20:53:31	Already processed thread '8pwarb'
# 2024-10-11 20:53:31	Already processed thread '8pwos2'
# 2024-10-11 20:53:31	Already processed thread '8pwpwb'
# 2024-10-11 20:53:31	Already processed thread '8pwqi7'
# 2024-10-11 20:53:31	Already processed thread '8pxjnv'
# 2024-10-11 20:53:31	Already processed thread '8py1zu'
# 2024-10-11 20:53:31	Already processed thread '8pyzkv'
# 2024-10-11 20:53:31	Already processed thread '8pyzvi'
# 2024-10-11 20:53:31	Already processed thread '8pz9hp'
# 2024-10-11 20:53:31	Already processed thread '8pzd0b'
# 2024-10-11 20:53:31	Already processed thread '8q0ahj'
# 2024-10-11 20:53:31	Already processed thread '8q0xqk'
# 2024-10-11 20:53:31	Already processed thread '8q03h2'
# 2024-10-11 20:53:31	Already processed thread '8q1pnd'
# 2024-10-11 20:53:32	Already processed thread '8q2rpa'
# 2024-10-11 20:53:32	Already processed thread '8q3m20'
# 2024-10-11 20:53:32	Already processed thread '8q3zac'
# 2024-10-11 20:53:32	Already processed thread '8q4g56'
# 2024-10-11 20:53:32	Already processed thread '8q4kpq'
# 2024-10-11 20:53:32	Already processed thread '8q4v3g'
# 2024-10-11 20:53:32	Already processed thread '8q5jqu'
# 2024-10-11 20:53:32	Already processed thread '8q5kyw'
# 2024-10-11 20:53:32	Already processed thread '8q5njr'
# 2024-10-11 20:53:32	Already processed thread '8q5s9v'
# 2024-10-11 20:53:32	Already processed thread '8q5ux2'
# 2024-10-11 20:53:32	Already processed thread '8q6ntn'
# 2024-10-11 20:53:32	Already processed thread '8q7bhz'
# 2024-10-11 20:53:32	Already processed thread '8q7jo0'
# 2024-10-11 20:53:32	Already processed thread '8q7p3s'
# 2024-10-11 20:53:32	Already processed thread '8q7rfp'
# 2024-10-11 20:53:32	Already processed thread '8q8cv5'
# 2024-10-11 20:53:32	Already processed thread '8q9duc'
# 2024-10-11 20:53:32	Already processed thread '8q34v1'
# 2024-10-11 20:53:32	Already processed thread '8q37vj'
# 2024-10-11 20:53:32	Already processed thread '8q62gf'
# 2024-10-11 20:53:32	Already processed thread '8q96w5'
# 2024-10-11 20:53:32	Already processed thread '8q329e'
# 2024-10-11 20:53:32	Already processed thread '8q355a'
# 2024-10-11 20:53:32	Already processed thread '8qas7d'
# 2024-10-11 20:53:32	Already processed thread '8qbls8'
# 2024-10-11 20:53:32	Already processed thread '8qc1kh'
# 2024-10-11 20:53:32	Already processed thread '8qcc53'
# 2024-10-11 20:53:32	Already processed thread '8qcmy4'
# 2024-10-11 20:53:32	Already processed thread '8qcuvu'
# 2024-10-11 20:53:32	Already processed thread '8qd0cg'
# 2024-10-11 20:53:32	Already processed thread '8qd79d'
# 2024-10-11 20:53:32	Already processed thread '8qdfeu'
# 2024-10-11 20:53:32	Already processed thread '8qdi4d'
# 2024-10-11 20:53:32	Already processed thread '8qdxbs'
# 2024-10-11 20:53:32	Already processed thread '8qe2r6'
# 2024-10-11 20:53:32	Already processed thread '8qe6xp'
# 2024-10-11 20:53:32	Already processed thread '8qed75'
# 2024-10-11 20:53:32	Already processed thread '8qefws'
# 2024-10-11 20:53:32	Already processed thread '8qerbs'
# 2024-10-11 20:53:32	Already processed thread '8qeseg'
# 2024-10-11 20:53:32	Already processed thread '8qeuf9'
# 2024-10-11 20:53:32	Already processed thread '8qf807'
# 2024-10-11 20:53:32	Already processed thread '8qff3i'
# 2024-10-11 20:53:32	Already processed thread '8qftwf'
# 2024-10-11 20:53:32	Already processed thread '8qge9x'
# 2024-10-11 20:53:32	Already processed thread '8qgpv6'
# 2024-10-11 20:53:32	Already processed thread '8qgvk6'
# 2024-10-11 20:53:32	Already processed thread '8qgy3e'
# 2024-10-11 20:53:32	Already processed thread '8qgzw6'
# 2024-10-11 20:53:32	Already processed thread '8qh0jl'
# 2024-10-11 20:53:32	Already processed thread '8qh3sl'
# 2024-10-11 20:53:32	Already processed thread '8qhiy2'
# 2024-10-11 20:53:32	Already processed thread '8qhmmy'
# 2024-10-11 20:53:32	Already processed thread '8qhxlx'
# 2024-10-11 20:53:32	Already processed thread '8qiell'
# 2024-10-11 20:53:32	Already processed thread '8qip08'
# 2024-10-11 20:53:32	Already processed thread '8qivla'
# 2024-10-11 20:53:32	Already processed thread '8qix4q'
# 2024-10-11 20:53:32	Already processed thread '8qji2k'
# 2024-10-11 20:53:32	Already processed thread '8qjs7u'
# 2024-10-11 20:53:32	Already processed thread '8qkftv'
# 2024-10-11 20:53:32	Already processed thread '8qkht1'
# 2024-10-11 20:53:32	Already processed thread '8qkqpl'
# 2024-10-11 20:53:32	Already processed thread '8qlcs1'
# 2024-10-11 20:53:32	Already processed thread '8qlde0'
# 2024-10-11 20:53:32	Already processed thread '8qlmu7'
# 2024-10-11 20:53:32	Already processed thread '8qlrxf'
# 2024-10-11 20:53:32	Already processed thread '8qmfve'
# 2024-10-11 20:53:32	Already processed thread '8qnccq'
# 2024-10-11 20:53:32	Already processed thread '8qncyn'
# 2024-10-11 20:53:32	Already processed thread '8qnd95'
# 2024-10-11 20:53:32	Already processed thread '8qnsx3'
# 2024-10-11 20:53:32	Already processed thread '8qnxle'
# 2024-10-11 20:53:32	Already processed thread '8qo1zy'
# 2024-10-11 20:53:32	Already processed thread '8qo8gv'
# 2024-10-11 20:53:32	Already processed thread '8qo9ww'
# 2024-10-11 20:53:32	Already processed thread '8qog4i'
# 2024-10-11 20:53:32	Already processed thread '8qovhp'
# 2024-10-11 20:53:32	Already processed thread '8qowwj'
# 2024-10-11 20:53:32	Already processed thread '8qq8v3'
# 2024-10-11 20:53:32	Already processed thread '8qq9i8'
# 2024-10-11 20:53:32	Already processed thread '8qqeig'
# 2024-10-11 20:53:32	Already processed thread '8qqiuh'
# 2024-10-11 20:53:32	Already processed thread '8qqmwi'
# 2024-10-11 20:53:32	Already processed thread '8qqpj6'
# 2024-10-11 20:53:32	Already processed thread '8qqtja'
# 2024-10-11 20:53:32	Already processed thread '8qqxq7'
# 2024-10-11 20:53:32	Already processed thread '8qr88r'
# 2024-10-11 20:53:32	Already processed thread '8qs8bs'
# 2024-10-11 20:53:32	Already processed thread '8qsudv'
# 2024-10-11 20:53:32	Already processed thread '8qsxzn'
# 2024-10-11 20:53:32	Already processed thread '8qtqd6'
# 2024-10-11 20:53:32	Already processed thread '8qtzm9'
# 2024-10-11 20:53:32	Already processed thread '8quiqw'
# 2024-10-11 20:53:32	Already processed thread '8qunlg'
# 2024-10-11 20:53:32	Already processed thread '8quxcz'
# 2024-10-11 20:53:32	Already processed thread '8quy4p'
# 2024-10-11 20:53:32	Already processed thread '8qv6db'
# 2024-10-11 20:53:32	Already processed thread '8qv7uo'
# 2024-10-11 20:53:32	Already processed thread '8qv41o'
# 2024-10-11 20:53:32	Already processed thread '8qvgix'
# 2024-10-11 20:53:32	Already processed thread '8qvtei'
# 2024-10-11 20:53:32	Already processed thread '8qw5a3'
# 2024-10-11 20:53:32	Already processed thread '8qweby'
# 2024-10-11 20:53:32	Already processed thread '8qwwrq'
# 2024-10-11 20:53:32	Already processed thread '8qxjr2'
# 2024-10-11 20:53:32	Already processed thread '8qxsji'
# 2024-10-11 20:53:32	Already processed thread '8qxynw'
# 2024-10-11 20:53:32	Already processed thread '8qyu38'
# 2024-10-11 20:53:32	Already processed thread '8qywqw'
# 2024-10-11 20:53:32	Already processed thread '8qzf6x'
# 2024-10-11 20:53:32	Already processed thread '8qzllh'
# 2024-10-11 20:53:32	Already processed thread '8qzp3t'
# 2024-10-11 20:53:32	Already processed thread '8qztxo'
# 2024-10-11 20:53:32	Already processed thread '8qzwl0'
# 2024-10-11 20:53:32	Already processed thread '8r0rwm'
# 2024-10-11 20:53:32	Already processed thread '8r0v4z'
# 2024-10-11 20:53:32	Already processed thread '8r0v8d'
# 2024-10-11 20:53:32	Already processed thread '8r0x0m'
# 2024-10-11 20:53:32	Already processed thread '8r036g'
# 2024-10-11 20:53:32	Already processed thread '8r1f9d'
# 2024-10-11 20:53:32	Already processed thread '8r1zjz'
# 2024-10-11 20:53:32	Already processed thread '8r2c24'
# 2024-10-11 20:53:32	Already processed thread '8r2psk'
# 2024-10-11 20:53:32	Already processed thread '8r2yi4'
# 2024-10-11 20:53:32	Already processed thread '8r3s1l'
# 2024-10-11 20:53:32	Already processed thread '8r3uhw'
# 2024-10-11 20:53:32	Already processed thread '8r5hzj'
# 2024-10-11 20:53:32	Already processed thread '8r6nhk'
# 2024-10-11 20:53:32	Already processed thread '8r6qod'
# 2024-10-11 20:53:32	Already processed thread '8r6tmd'
# 2024-10-11 20:53:32	Already processed thread '8r8exo'
# 2024-10-11 20:53:32	Already processed thread '8r9pw3'
# 2024-10-11 20:53:32	Already processed thread '8r11i9'
# 2024-10-11 20:53:32	Already processed thread '8r28nz'
# 2024-10-11 20:53:32	Already processed thread '8r38z2'
# 2024-10-11 20:53:32	Already processed thread '8r61cp'
# 2024-10-11 20:53:32	Already processed thread '8r67a8'
# 2024-10-11 20:53:32	Already processed thread '8r73bm'
# 2024-10-11 20:53:32	Already processed thread '8r80gp'
# 2024-10-11 20:53:32	Already processed thread '8r802e'
# 2024-10-11 20:53:32	Already processed thread '8ra2h7'
# 2024-10-11 20:53:32	Already processed thread '8rann5'
# 2024-10-11 20:53:32	Already processed thread '8raop8'
# 2024-10-11 20:53:32	Already processed thread '8rb0i2'
# 2024-10-11 20:53:32	Already processed thread '8rb926'
# 2024-10-11 20:53:32	Already processed thread '8rbgfi'
# 2024-10-11 20:53:32	Already processed thread '8rbwz1'
# 2024-10-11 20:53:32	Already processed thread '8rccx5'
# 2024-10-11 20:53:32	Already processed thread '8rcj2k'
# 2024-10-11 20:53:32	Already processed thread '8rcvqq'
# 2024-10-11 20:53:32	Already processed thread '8rdp6r'
# 2024-10-11 20:53:32	Already processed thread '8re1t0'
# 2024-10-11 20:53:32	Already processed thread '8rezff'
# 2024-10-11 20:53:32	Already processed thread '8rfl4t'
# 2024-10-11 20:53:32	Already processed thread '8rfqen'
# 2024-10-11 20:53:32	Already processed thread '8rfvfn'
# 2024-10-11 20:53:32	Already processed thread '8rfvmj'
# 2024-10-11 20:53:32	Already processed thread '8rgav7'
# 2024-10-11 20:53:32	Already processed thread '8rgki2'
# 2024-10-11 20:53:32	Already processed thread '8rgsw8'
# 2024-10-11 20:53:32	Already processed thread '8rhq8f'
# 2024-10-11 20:53:32	Already processed thread '8rhupr'
# 2024-10-11 20:53:32	Already processed thread '8rhv4x'
# 2024-10-11 20:53:32	Already processed thread '8rhyw2'
# 2024-10-11 20:53:32	Already processed thread '8ri7lu'
# 2024-10-11 20:53:32	Already processed thread '8rif5b'
# 2024-10-11 20:53:32	Already processed thread '8rimlr'
# 2024-10-11 20:53:32	Already processed thread '8riskb'
# 2024-10-11 20:53:32	Already processed thread '8risn3'
# 2024-10-11 20:53:32	Already processed thread '8rk756'
# 2024-10-11 20:53:32	Already processed thread '8rkjxm'
# 2024-10-11 20:53:32	Already processed thread '8rkxmj'
# 2024-10-11 20:53:32	Already processed thread '8rl851'
# 2024-10-11 20:53:32	Already processed thread '8rlayi'
# 2024-10-11 20:53:32	Already processed thread '8rld18'
# 2024-10-11 20:53:32	Already processed thread '8rm4zo'
# 2024-10-11 20:53:32	Already processed thread '8rmk91'
# 2024-10-11 20:53:32	Already processed thread '8rml3m'
# 2024-10-11 20:53:32	Already processed thread '8rnbg0'
# 2024-10-11 20:53:32	Already processed thread '8rnngf'
# 2024-10-11 20:53:32	Already processed thread '8ro9ms'
# 2024-10-11 20:53:32	Already processed thread '8roh41'
# 2024-10-11 20:53:32	Already processed thread '8ropsp'
# 2024-10-11 20:53:32	Already processed thread '8rp961'
# ...
# 2024-10-12 01:58:09	  * Saving 3 responses to file
# 2024-10-12 01:58:09	    - 230217845.v1.json
# 2024-10-12 01:58:09	    - 230217845.v2.json
# 2024-10-12 01:58:09	    - 230217845.v3.json
# 2024-10-12 01:58:09	Processing of thread '230225914'
# 2024-10-12 01:58:29	  * Saving 3 responses to file
# 2024-10-12 01:58:29	    - 230225914.v1.json
# 2024-10-12 01:58:29	    - 230225914.v2.json
# 2024-10-12 01:58:29	    - 230225914.v3.json
# 2024-10-12 01:58:29	Processing of thread '230229020'
# 2024-10-12 01:58:43	  * Saving 3 responses to file
# 2024-10-12 02:05:36	    - 230308040.v3.json
# 2024-10-12 02:05:36	Processing of thread '230309755'
# 2024-10-12 02:06:02	  * Saving 3 responses to file
# 2024-10-12 02:06:02	    - 230309755.v1.json
# 2024-10-12 02:06:02	    - 230309755.v2.json
# 2024-10-12 02:06:02	    - 230309755.v3.json
# 2024-10-12 02:06:02	Processing of thread '230316684'
# 2024-10-12 02:06:22	  * Saving 3 responses to file
# 2024-10-12 02:06:22	    - 230316684.v1.json
# 2024-10-12 02:06:22	    - 230316684.v2.json
# 2024-10-12 02:06:22	    - 230316684.v3.json
# 2024-10-12 02:06:22	Processing of thread '230318820'
# 2024-10-12 02:06:44	  * Saving 3 responses to file
# 2024-10-12 02:06:44	    - 230318820.v1.json
# 2024-10-12 02:06:44	    - 230318820.v2.json
# 2024-10-12 02:06:44	    - 230318820.v3.json
# 2024-10-12 02:06:44	Processing of thread '230329558'
# 2024-10-12 02:06:54	  * Saving 3 responses to file
# 2024-10-12 02:06:54	    - 230329558.v1.json
# 2024-10-12 02:06:54	    - 230329558.v2.json
# 2024-10-12 02:06:54	    - 230329558.v3.json
# 2024-10-12 02:06:54	Processing of thread '230344835'
# 2024-10-12 02:07:16	  * Saving 3 responses to file
# 2024-10-12 02:07:16	    - 230344835.v1.json
# 2024-10-12 02:07:16	    - 230344835.v2.json
# 2024-10-12 02:07:16	    - 230344835.v3.json
# 2024-10-12 02:07:16	Processing of thread '230354762'
# 2024-10-12 02:07:30	  * Saving 3 responses to file
# 2024-10-12 02:07:30	    - 230354762.v1.json
# 2024-10-12 02:07:30	    - 230354762.v2.json
# 2024-10-12 02:07:30	    - 230354762.v3.json
# 2024-10-12 02:07:30	Processing of thread '230365358'
# 2024-10-12 02:07:47	  * Saving 3 responses to file
# 2024-10-12 02:07:47	    - 230365358.v1.json
# 2024-10-12 02:07:47	    - 230365358.v2.json
# 2024-10-12 02:07:47	    - 230365358.v3.json
# 2024-10-12 02:07:47	Processing of thread '230366488'
# 2024-10-12 02:08:01	  * Saving 3 responses to file
# 2024-10-12 02:08:01	    - 230366488.v1.json
# 2024-10-12 02:08:01	    - 230366488.v2.json
# 2024-10-12 02:08:01	    - 230366488.v3.json
# 2024-10-12 02:08:01	Processing of thread '230370119'
# 2024-10-12 02:08:16	  * Saving 3 responses to file
# 2024-10-12 02:08:16	    - 230370119.v1.json
# 2024-10-12 02:08:16	    - 230370119.v2.json
# 2024-10-12 02:08:16	    - 230370119.v3.json
# 2024-10-12 02:08:16	Processing of thread '230371624'
# 2024-10-12 02:08:29	  * Saving 3 responses to file
# 2024-10-12 02:08:29	    - 230371624.v1.json
# 2024-10-12 02:08:29	    - 230371624.v2.json
# 2024-10-12 02:08:29	    - 230371624.v3.json
# 2024-10-12 02:08:29	Processing of thread '230375553'
# 2024-10-12 02:08:53	  * Saving 3 responses to file
# 2024-10-12 02:08:53	    - 230375553.v1.json
# 2024-10-12 02:08:53	    - 230375553.v2.json
# 2024-10-12 02:08:53	    - 230375553.v3.json
# 2024-10-12 02:15:38	    - 230490255.v2.json
# 2024-10-12 02:15:38	    - 230490255.v3.json
# 2024-10-12 02:15:38	Processing of thread '230492694'
# 2024-10-12 02:15:53	  * Saving 3 responses to file
# 2024-10-12 02:15:53	    - 230492694.v1.json
# 2024-10-12 02:15:53	    - 230492694.v2.json
# 2024-10-12 02:15:53	    - 230492694.v3.json
# 2024-10-12 02:15:53	Processing of thread '230494225'
# 2024-10-12 02:16:11	  * Saving 3 responses to file
# 2024-10-12 02:16:11	    - 230494225.v1.json
# 2024-10-12 02:16:11	    - 230494225.v2.json
# 2024-10-12 02:16:11	    - 230494225.v3.json
# 2024-10-12 02:16:11	Processing of thread '230497059'
# 2024-10-12 02:16:26	  * Saving 3 responses to file
# 2024-10-12 02:16:26	    - 230497059.v1.json
# 2024-10-12 02:16:26	    - 230497059.v2.json
# 2024-10-12 02:16:26	    - 230497059.v3.json
# 2024-10-12 02:16:26	Processing of thread '230499323'
# 2024-10-12 02:16:46	  * Saving 3 responses to file
# 2024-10-12 02:16:46	    - 230499323.v1.json
# 2024-10-12 02:16:46	    - 230499323.v2.json
# 2024-10-12 02:16:46	    - 230499323.v3.json
# 2024-10-12 02:16:46	Processing of thread '230500913'
# 2024-10-12 02:17:06	  * Saving 3 responses to file
# 2024-10-12 02:17:06	    - 230500913.v1.json
# 2024-10-12 02:17:06	    - 230500913.v2.json
# 2024-10-12 02:17:06	    - 230500913.v3.json
# 2024-10-12 02:17:06	Processing of thread '230516160'
# 2024-10-12 02:17:21	  * Saving 3 responses to file
# 2024-10-12 02:17:21	    - 230516160.v1.json
# 2024-10-12 02:17:21	    - 230516160.v2.json
# 2024-10-12 02:17:21	    - 230516160.v3.json
# 2024-10-12 02:17:21	Processing of thread '230519720'
# 2024-10-12 02:17:44	  * Saving 3 responses to file
# 2024-10-12 02:17:44	    - 230519720.v1.json
# 2024-10-12 02:17:44	    - 230519720.v2.json
# 2024-10-12 02:17:44	    - 230519720.v3.json
# 2024-10-12 02:17:44	Processing of thread '230531422'
# 2024-10-12 02:18:01	  * Saving 3 responses to file
# 2024-10-12 02:18:01	    - 230531422.v1.json
# 2024-10-12 02:18:01	    - 230531422.v2.json
# 2024-10-12 02:18:01	    - 230531422.v3.json
# 2024-10-12 02:18:01	Processing of thread '230534269'
# 2024-10-12 02:18:19	  * Saving 3 responses to file
# 2024-10-12 02:18:19	    - 230534269.v1.json
# 2024-10-12 02:18:19	    - 230534269.v2.json
# 2024-10-12 02:18:19	    - 230534269.v3.json

# %% [markdown]
# To make things easier for us in the future, let's create some special subsets of this dataset.

# %% [markdown]
# ## 4. OpenAI
#
# Load the OpenAI library and set the appropriate API key.

# %% [markdown]
# # Workflow
#
# - Annotate replies in Excel spreadsheet for solved requests
# - Try out different ChatGPT prompts and document them
#   - Original request
#   - Original request + instructional prompt
#   - Original request + instructional prompt + admit uncertainty
#   - Original request + instructional prompt + admit uncertainty + answer explanation
# - Run all request (solved first!) through ChatGPT
# - Check how many requests ChatGPT is able to solve
